# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## Extracting the array of migration relevant CAMEO events

# %%
CAMEOcodes_handle = pd.read_csv("../data/CAMEO_table_clean.csv")

# %% [markdown]
# ##### I have to drop the first rows and take then only the inluded yes variables

# %%
CAMEOs = CAMEOcodes_handle.copy()

# %%
selectedCodes = CAMEOs.iloc[:, 0].str.extract(r"^(.*):")

# %%
selected_np = selectedCodes.iloc[:, 0].to_numpy()

# %%
selected = selected_np.tolist()

# %%
selected = np.char.replace(selected, "Social", "6")

# %%
CAMEO_selection = np.empty_like(selected)
for i, item in np.ndenumerate(selected):
    CAMEO_selection[i] = re.sub(r"\D", "", item)

# %%
CAMEO_selection.tolist()
# Out:
# ['0232',
#  '0234',
#  '0254',
#  '0255',
#  '0256',
#  '026',
#  '027',
#  '028',
#  '0354',
#  '0355',
#  '0356',
#  '036',
#  '037',
#  '038',
#  '081',
#  '0871',
#  '0872',
#  '0873',
#  '0874',
#  '093',
#  '094',
#  '1012',
#  '1014',
#  '1032',
#  '1034',
#  '1054',
#  '1055',
#  '1056',
#  '106',
#  '107',
#  '108',
#  '1123',
#  '1124',
#  '1125',
#  '1244',
#  '1245',
#  '1246',
#  '125',
#  '126',
#  '127',
#  '138',
#  '1382',
#  '1383',
#  '1384',
#  '1385',
#  '139',
#  '150',
#  '152',
#  '154',
#  '155',
#  '164',
#  '165',
#  '166',
#  '1661',
#  '1662',
#  '1663',
#  '170',
#  '176',
#  '180',
#  '190',
#  '191',
#  '192',
#  '193',
#  '194',
#  '195',
#  '1951',
#  '1952',
#  '196',
#  '200',
#  '204',
#  '2041',
#  '2042',
#  '1033',
#  '023',
#  '0231',
#  '1011',
#  '103',
#  '1031',
#  '024',
#  '0241',
#  '0244',
#  '034',
#  '0341',
#  '0342',
#  '0344',
#  '035',
#  '083',
#  '0831',
#  '0832',
#  '0834',
#  '091',
#  '104',
#  '1041',
#  '1042',
#  '1044',
#  '105',
#  '1121',
#  '123',
#  '1231',
#  '1232',
#  '1234',
#  '124',
#  '1241',
#  '128',
#  '0243',
#  '0251',
#  '0253',
#  '0343',
#  '0351',
#  '0353',
#  '075',
#  '0811',
#  '0812',
#  '0813',
#  '0814',
#  '0833',
#  '092',
#  '1043',
#  '1051',
#  '1053',
#  '1122',
#  '1233',
#  '1243',
#  '1322',
#  '1323',
#  '1324',
#  '137',
#  '151',
#  '153',
#  '1711',
#  '172',
#  '1721',
#  '1722',
#  '1723',
#  '1724',
#  '173',
#  '174',
#  '175',
#  '181',
#  '1822',
#  '1823',
#  '201',
#  '202',
#  '203',
#  '0233',
#  '0252',
#  '0352',
#  '082',
#  '084',
#  '0841',
#  '0842',
#  '1052',
#  '113',
#  '1242',
#  '133',
#  '1381',
#  '140',
#  '141',
#  '1411',
#  '1412',
#  '1413',
#  '1414',
#  '142',
#  '1421',
#  '1422',
#  '1423',
#  '1424',
#  '143',
#  '1431',
#  '1432',
#  '1433',
#  '1434',
#  '144',
#  '1441',
#  '1442',
#  '1443',
#  '1444',
#  '145',
#  '1451',
#  '1452',
#  '1453',
#  '1454',
#  '171',
#  '1712',
#  '182',
#  '1821',
#  '183',
#  '1831',
#  '1832',
#  '1833',
#  '1834',
#  '184',
#  '185',
#  '186',
#  '07',
#  '070',
#  '071',
#  '072',
#  '073',
#  '074',
#  '085',
#  '086',
#  '0861',
#  '0862',
#  '0863',
#  '13',
#  '16',
#  '0211',
#  '0212',
#  '0311',
#  '032',
#  '033',
#  '0331',
#  '0332',
#  '0333',
#  '0334',
#  '039',
#  '046',
#  '050',
#  '054',
#  '061',
#  '062',
#  '087',
#  '1211',
#  '1212',
#  '122',
#  '1221',
#  '1222',
#  '1223',
#  '1224',
#  '14',
#  '15',
#  '162',
#  '1621',
#  '1622',
#  '1623',
#  '163']

# %%
CAMEOs["code"] = pd.Series(data=CAMEO_selection)
CAMEOs
# Out:
#                                   GDELT code and topic Included Sign  \
# 0                        0232: Appeal for military aid      Yes    +
# 1    0234: Appeal for military protection or peacek...      Yes    +
# 2    0254: Appeal for easing of economic sanctions,...      Yes    +
# 3    0255: Appeal for target to allow international...      Yes    +
# 4    025: Social: Appeal for de-escalation of milit...      Yes    +
# ..                                                 ...      ...  ...
# 232  1Social2: Reduce or stop material aid, not spe...      Yes    +
# 233      1Social21: Reduce or stop economic assistance      Yes    +
# 234      1Social22: Reduce or stop military assistance      Yes    +
# 235  1Social23: Reduce or stop humanitarian assistance      Yes    +
# 236    1Social3: Impose embargo, boycott, or sanctions      Yes    +
#
#     Category\nlabel  Strength  code
# 0          Conflict         1  0232
# 1          Conflict         1  0234
# 2          Economic         1  0254
# 3          Conflict         1  0255
# 4          Conflict         1  0256
# ..              ...       ...   ...
# 232        Conflict         2   162
# 233        Economic         2  1621
# 234        Conflict         2  1622
# 235        Conflict         2  1623
# 236        Conflict         2   163
#
# [237 rows x 6 columns]

# %% [markdown]
# ##### Checking the relevance of the general root CAMEO tags

# %%
# In the CAMEO code selection table of the paper, they left unspecified general CAMEO class codes:
CAMEOs[CAMEOs["code"].str.len() == 2]
# Out:
#           GDELT code and topic Included Sign Category\nlabel  Strength code
# 194            07: PROVIDE AID      Yes    -        Conflict         1   07
# 205               13: THREATEN      Yes    +        Conflict         1   13
# 206  1Social: REDUCE RELATIONS      Yes    +        Conflict         1   16
# 230                14: PROTEST      Yes    +          Social         1   14
# 231  15: EXHIBIT FORCE POSTURE      Yes    +        Conflict         1   15

# %% [markdown]
# ##### Deciding, for simplicity purposes, drop the general CAMEO codes

# %%
relevant_CAMEOS = CAMEOs.drop(CAMEOs[CAMEOs["code"].str.len() == 2].index)
relevant_CAMEOS = CAMEOs.drop("Included", axis=1)
relevant_CAMEOS
# Out:
#                                   GDELT code and topic Sign Category\nlabel  \
# 0                        0232: Appeal for military aid    +        Conflict
# 1    0234: Appeal for military protection or peacek...    +        Conflict
# 2    0254: Appeal for easing of economic sanctions,...    +        Economic
# 3    0255: Appeal for target to allow international...    +        Conflict
# 4    025: Social: Appeal for de-escalation of milit...    +        Conflict
# ..                                                 ...  ...             ...
# 232  1Social2: Reduce or stop material aid, not spe...    +        Conflict
# 233      1Social21: Reduce or stop economic assistance    +        Economic
# 234      1Social22: Reduce or stop military assistance    +        Conflict
# 235  1Social23: Reduce or stop humanitarian assistance    +        Conflict
# 236    1Social3: Impose embargo, boycott, or sanctions    +        Conflict
#
#      Strength  code
# 0           1  0232
# 1           1  0234
# 2           1  0254
# 3           1  0255
# 4           1  0256
# ..        ...   ...
# 232         2   162
# 233         2  1621
# 234         2  1622
# 235         2  1623
# 236         2   163
#
# [237 rows x 5 columns]

# %%
relevant_CAMEOS = relevant_CAMEOS.rename(
    columns={
        "GDELT code and topic": "description",
        "Sign": "sign",
        "Category\nlabel": "label",
        "Strength": "weight",
    }
)

# %%
relevant_CAMEOS["weight"] = relevant_CAMEOS["sign"] + relevant_CAMEOS["weight"].astype(
    "str"
)

# %%
relevant_CAMEOS["weight"] = relevant_CAMEOS["weight"].astype("int")

# %%
relevant_CAMEOS = relevant_CAMEOS.drop("sign", axis=1)

# %%
relevant_CAMEOS = relevant_CAMEOS.loc[:, ::-1]

# %%
relevant_CAMEOS["label"] = (
    relevant_CAMEOS["label"].str.lower().replace("governanc\ne", "governance")
)

# %%
relevant_CAMEOS.to_csv("../data/CAMEO_weights.csv")

# %% [markdown]
# ## Preprocessing GDELT 1.0

# %% [markdown]
# #### Adding the column names first.

# %%
header = "GLOBALEVENTID   SQLDATE MonthYear   Year    FractionDate	Actor1Code	Actor1Name	Actor1CountryCode	Actor1KnownGroupCode	Actor1EthnicCode	Actor1Religion1Code	Actor1Religion2Code	Actor1Type1Code	Actor1Type2Code	Actor1Type3Code	Actor2Code	Actor2Name	Actor2CountryCode	Actor2KnownGroupCode	Actor2EthnicCode	Actor2Religion1Code	Actor2Religion2Code	Actor2Type1Code	Actor2Type2Code	Actor2Type3Code	IsRootEvent	EventCode	EventBaseCode	EventRootCode	QuadClass	GoldsteinScale	NumMentions	NumSources	NumArticles	AvgTone	Actor1Geo_Type	Actor1Geo_FullName	Actor1Geo_CountryCode	Actor1Geo_ADM1Code	Actor1Geo_Lat	Actor1Geo_Long	Actor1Geo_FeatureID	Actor2Geo_Type	Actor2Geo_FullName	Actor2Geo_CountryCode	Actor2Geo_ADM1Code	Actor2Geo_Lat	Actor2Geo_Long	Actor2Geo_FeatureID	ActionGeo_Type	ActionGeo_FullName	ActionGeo_CountryCode	ActionGeo_ADM1Code	ActionGeo_Lat	ActionGeo_Long	ActionGeo_FeatureID	DATEADDED	SOURCEURL"
header = header.split()
header
# Out:
# ['GLOBALEVENTID',
#  'SQLDATE',
#  'MonthYear',
#  'Year',
#  'FractionDate',
#  'Actor1Code',
#  'Actor1Name',
#  'Actor1CountryCode',
#  'Actor1KnownGroupCode',
#  'Actor1EthnicCode',
#  'Actor1Religion1Code',
#  'Actor1Religion2Code',
#  'Actor1Type1Code',
#  'Actor1Type2Code',
#  'Actor1Type3Code',
#  'Actor2Code',
#  'Actor2Name',
#  'Actor2CountryCode',
#  'Actor2KnownGroupCode',
#  'Actor2EthnicCode',
#  'Actor2Religion1Code',
#  'Actor2Religion2Code',
#  'Actor2Type1Code',
#  'Actor2Type2Code',
#  'Actor2Type3Code',
#  'IsRootEvent',
#  'EventCode',
#  'EventBaseCode',
#  'EventRootCode',
#  'QuadClass',
#  'GoldsteinScale',
#  'NumMentions',
#  'NumSources',
#  'NumArticles',
#  'AvgTone',
#  'Actor1Geo_Type',
#  'Actor1Geo_FullName',
#  'Actor1Geo_CountryCode',
#  'Actor1Geo_ADM1Code',
#  'Actor1Geo_Lat',
#  'Actor1Geo_Long',
#  'Actor1Geo_FeatureID',
#  'Actor2Geo_Type',
#  'Actor2Geo_FullName',
#  'Actor2Geo_CountryCode',
#  'Actor2Geo_ADM1Code',
#  'Actor2Geo_Lat',
#  'Actor2Geo_Long',
#  'Actor2Geo_FeatureID',
#  'ActionGeo_Type',
#  'ActionGeo_FullName',
#  'ActionGeo_CountryCode',
#  'ActionGeo_ADM1Code',
#  'ActionGeo_Lat',
#  'ActionGeo_Long',
#  'ActionGeo_FeatureID',
#  'DATEADDED',
#  'SOURCEURL']

# %%
handle = pd.read_table(
    "../data/gdelt_data/extracted/20230511.export.CSV",
    names=header,
    dtype={"EventCode": str},
)
handle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174898 entries, 0 to 174897
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   GLOBALEVENTID          174898 non-null  int64
#  1   SQLDATE                174898 non-null  int64
#  2   MonthYear              174898 non-null  int64
#  3   Year                   174898 non-null  int64
#  4   FractionDate           174898 non-null  float64
#  5   Actor1Code             158608 non-null  object
#  6   Actor1Name             158608 non-null  object
#  7   Actor1CountryCode      99651 non-null   object
#  8   Actor1KnownGroupCode   2400 non-null    object
#  9   Actor1EthnicCode       881 non-null     object
#  10  Actor1Religion1Code    1970 non-null    object
#  11  Actor1Religion2Code    456 non-null     object
#  12  Actor1Type1Code        76221 non-null   object
#  13  Actor1Type2Code        4993 non-null    object
#  14  Actor1Type3Code        104 non-null     object
#  15  Actor2Code             127086 non-null  object
#  16  Actor2Name             127086 non-null  object
#  17  Actor2CountryCode      79952 non-null   object
#  18  Actor2KnownGroupCode   1809 non-null    object
#  19  Actor2EthnicCode       715 non-null     object
#  20  Actor2Religion1Code    1819 non-null    object
#  21  Actor2Religion2Code    408 non-null     object
#  22  Actor2Type1Code        60253 non-null   object
#  23  Actor2Type2Code        3591 non-null    object
#  24  Actor2Type3Code        71 non-null      object
#  25  IsRootEvent            174898 non-null  int64
#  26  EventCode              174898 non-null  object
#  27  EventBaseCode          174898 non-null  int64
#  28  EventRootCode          174898 non-null  int64
#  29  QuadClass              174898 non-null  int64
#  30  GoldsteinScale         174898 non-null  float64
#  31  NumMentions            174898 non-null  int64
#  32  NumSources             174898 non-null  int64
#  33  NumArticles            174898 non-null  int64
#  34  AvgTone                174898 non-null  float64
#  35  Actor1Geo_Type         174898 non-null  int64
#  36  Actor1Geo_FullName     154265 non-null  object
#  37  Actor1Geo_CountryCode  154376 non-null  object
#  38  Actor1Geo_ADM1Code     154376 non-null  object
#  39  Actor1Geo_Lat          154265 non-null  float64
#  40  Actor1Geo_Long         154348 non-null  float64
#  41  Actor1Geo_FeatureID    154376 non-null  object
#  42  Actor2Geo_Type         174898 non-null  int64
#  43  Actor2Geo_FullName     123756 non-null  object
#  44  Actor2Geo_CountryCode  123827 non-null  object
#  45  Actor2Geo_ADM1Code     123827 non-null  object
#  46  Actor2Geo_Lat          123756 non-null  float64
#  47  Actor2Geo_Long         123811 non-null  float64
#  48  Actor2Geo_FeatureID    123827 non-null  object
#  49  ActionGeo_Type         174898 non-null  int64
#  50  ActionGeo_FullName     170107 non-null  object
#  51  ActionGeo_CountryCode  170232 non-null  object
#  52  ActionGeo_ADM1Code     170232 non-null  object
#  53  ActionGeo_Lat          170107 non-null  float64
#  54  ActionGeo_Long         170203 non-null  float64
#  55  ActionGeo_FeatureID    170232 non-null  object
#  56  DATEADDED              174898 non-null  int64
#  57  SOURCEURL              174898 non-null  object
# dtypes: float64(9), int64(15), object(34)
# memory usage: 77.4+ MB

# %%
handle.to_csv("../data/gdelt_data/gdelt_example.csv")

# %%
handle["GLOBALEVENTID"].value_counts().value_counts()
# Out:
# 1    174898
# Name: GLOBALEVENTID, dtype: int64

# %% [markdown]
# #### Defining feature extraction functions for a gdelt daily event table

# %%
CAMEO_weights = pd.read_csv(
    "../data/CAMEO_weights.csv", index_col=0, dtype={"code": str}
)
CAMEO_weights = CAMEO_weights.set_index("code")
CAMEO_weights

# %%
handle = pd.read_csv(
    "../data/gdelt_data/gdelt_example.csv", index_col=0, dtype={"EventCode": str}
)

# %%
eventdf = handle.copy()
eventdf
# Out:
#         GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0          1101511638  20220511     202205  2022     2022.3589        NaN
# 1          1101511639  20220511     202205  2022     2022.3589        NaN
# 2          1101511640  20220511     202205  2022     2022.3589        NaN
# 3          1101511641  20220511     202205  2022     2022.3589        NaN
# 4          1101511642  20220511     202205  2022     2022.3589        BUS
# ...               ...       ...        ...   ...           ...        ...
# 174893     1101765385  20230511     202305  2023     2023.3589        ZWE
# 174894     1101765386  20230511     202305  2023     2023.3589        ZWE
# 174895     1101765387  20230511     202305  2023     2023.3589        chm
# 174896     1101765388  20230511     202305  2023     2023.3589        chm
# 174897     1101765389  20230511     202305  2023     2023.3589        sco
#
#        Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0             NaN               NaN                  NaN              NaN
# 1             NaN               NaN                  NaN              NaN
# 2             NaN               NaN                  NaN              NaN
# 3             NaN               NaN                  NaN              NaN
# 4         COMPANY               NaN                  NaN              NaN
# ...           ...               ...                  ...              ...
# 174893   ZIMBABWE               ZWE                  NaN              NaN
# 174894   ZIMBABWE               ZWE                  NaN              NaN
# 174895       MARI               NaN                  NaN              chm
# 174896       MARI               NaN                  NaN              chm
# 174897   SCOTTISH               NaN                  NaN              sco
#
#         ... Actor2Geo_FeatureID ActionGeo_Type  \
# 0       ...             1660757              3
# 1       ...             1492837              3
# 2       ...             1492837              2
# 3       ...             1660757              3
# 4       ...                 NaN              0
# ...     ...                 ...            ...
# 174893  ...            -2312291              4
# 174894  ...            -2312291              4
# 174895  ...                  RP              1
# 174896  ...            -2597039              4
# 174897  ...                 NaN              4
#
#                               ActionGeo_FullName ActionGeo_CountryCode  \
# 0           Hollywood, California, United States                    US
# 1              Danville, Virginia, United States                    US
# 2                        Virginia, United States                    US
# 3           Hollywood, California, United States                    US
# 4                                            NaN                   NaN
# ...                                          ...                   ...
# 174893        Harare, Mashonaland East, Zimbabwe                    ZI
# 174894        Harare, Mashonaland East, Zimbabwe                    ZI
# 174895                               Philippines                    RP
# 174896     Glasgow, Glasgow City, United Kingdom                    UK
# 174897  Peterhead, Aberdeenshire, United Kingdom                    UK
#
#        ActionGeo_ADM1Code ActionGeo_Lat ActionGeo_Long ActionGeo_FeatureID  \
# 0                    USCA       34.0983     -118.32700             1660757
# 1                    USVA       36.5860      -79.39500             1492837
# 2                    USVA       37.7680      -78.20570                  VA
# 3                    USCA       34.0983     -118.32700             1660757
# 4                     NaN           NaN            NaN                 NaN
# ...                   ...           ...            ...                 ...
# 174893               ZI04      -17.8178       31.04470            -2312291
# 174894               ZI04      -17.8178       31.04470            -2312291
# 174895                 RP       13.0000      122.00000                  RP
# 174896               UKV2       55.8333       -4.25000            -2597039
# 174897               UKT6       57.5000       -1.78333            -2605290
#
#        DATEADDED                                          SOURCEURL
# 0       20230511  https://www.ktvq.com/news/local-news/labor-of-...
# 1       20230511  https://godanriver.com/news/local/govt-and-pol...
# 2       20230511  https://godanriver.com/news/local/govt-and-pol...
# 3       20230511  https://www.ktvq.com/news/local-news/labor-of-...
# 4       20230511  https://finance.yahoo.com/news/zheneng-jinjian...
# ...          ...                                                ...
# 174893  20230511   https://www.herald.co.zw/culture-month-launched/
# 174894  20230511   https://www.herald.co.zw/culture-month-launched/
# 174895  20230511  https://www.hellenicshippingnews.com/a-friendl...
# 174896  20230511  https://www.hellenicshippingnews.com/a-friendl...
# 174897  20230511  https://www.dailyrecord.co.uk/lifestyle/money/...
#
# [174898 rows x 58 columns]

# %%
def eventdf_FE(eventdf, CAMEOtags):
    # Extract relevant features of the big GDELT day table
    df = eventdf[
        [
            "SQLDATE",
            "IsRootEvent",
            "EventCode"
            # ,'QuadClass'           Excluded as we build the event indices proposed by the paper
            # ,'GoldsteinScale'
            ,
            "ActionGeo_CountryCode"
            # ,'SOURCEURL'           As we are going to agregate all these for a month, it is not relevant anymore to track it back
        ]
    ].copy()
    # Extract only root events as done in the paper
    df = df[df["IsRootEvent"] == 1]
    df = df.drop("IsRootEvent", axis=1)
    # Extract only the relevant events
    df = df[df["EventCode"].isin(CAMEOtags)]
    # drop NaNs, as they are mostly in the CountryCode
    df = df.dropna()
    df = df.reset_index(drop=True)
    df = df.rename(
        columns={
            "SQLDATE": "date",
            "EventCode": "code",
            "ActionGeo_CountryCode": "country",
        }
    )
    return df

# %%
def get_category_weights(eventdf, CAMEO_weights):
    # Filter the giant day GDELT event data to its relevant columns
    df = eventdf_FE(eventdf, CAMEO_weights.index.tolist())
    # Aggregate them by country and event-type-code
    # and get the quantity of the single event-types for in each country
    df = df.groupby(["country", "code"]).size()
    df = pd.DataFrame(df).reset_index().rename(columns={0: "count"})
    # Now we are associating each event-type to their corresponding
    # weights and labels describe in the CAMEO_weights reference table
    df["category"] = pd.NA
    for i, row in df.loc[:, ["code"]].iterrows():
        weight = CAMEO_weights.loc[row["code"]]["weight"]
        count = df["count"].iloc[i]
        df["count"].iloc[i] = count * weight / 3
        df["category"].iloc[i] = CAMEO_weights.loc[row["code"]]["label"]
    # Done this, we don't need the code column anymore
    # so we drop it, an agreggate by country and category
    df = df.drop("code", axis=1).groupby(["country", "category"]).sum()
    return df

# %%
day_weights = get_category_weights(eventdf, CAMEO_weights)
day_weights
# Out:
# /tmp/ipykernel_7794/3861380352.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'].iloc[i] = count*weight/3
# /tmp/ipykernel_7794/3861380352.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'].iloc[i] = CAMEO_weights.loc[row['code']]['label']

# %%
ec2 = day_weights.copy()
ec2["count"] + day_weights["count"]
# Out:
# country  category
# AA       Conflict      7.333333
#          Political    47.333333
# AC       Conflict      0.000000
# AE       Conflict    -30.000000
#          Economic    -41.333333
#                         ...
# ZA       Social        0.666667
# ZI       Conflict     16.000000
#          Economic    -26.666667
#          Political    41.333333
#          Social        4.666667
# Name: count, Length: 689, dtype: float64

# %% [markdown]
# ##### Next steps: to extract the push factors, aggregate them by week and or month, following the event indeces methodology in the paper

# %%
eventdf
# Out:
#         SQLDATE EventCode ActionGeo_CountryCode
# 0      20220511       180                    US
# 1      20220511       180                    US
# 2      20230411       190                    PK
# 3      20230411       190                    PK
# 4      20230411       190                    PK
# ...         ...       ...                   ...
# 33894  20230511       070                    CE
# 33895  20230511       070                    CE
# 33896  20230511       070                    VM
# 33897  20230511      0841                    VM
# 33898  20230511      0841                    VM
#
# [33899 rows x 3 columns]

# %%
def Extract_PFI():
    pass

# %%
eventdf.dropna().isna().sum()
# Out:
# SQLDATE                  0
# EventCode                0
# QuadClass                0
# GoldsteinScale           0
# ActionGeo_CountryCode    0
# SOURCEURL                0
# dtype: int64
