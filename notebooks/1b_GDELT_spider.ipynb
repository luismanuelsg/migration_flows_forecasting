# %%
import zipfile
import os
import urllib.request
from datetime import datetime, timedelta
import pandas as pd

import warnings

warnings.filterwarnings("ignore")

# %%
def eventdf_FE(eventdf, CAMEOtags):
    """Filter the giant day GDELT event data to its relevant columns"""
    df = eventdf[
        [
            "SQLDATE",
            "IsRootEvent",
            "EventCode"
            # ,'QuadClass'           Excluded as we build the event indices proposed by the paper
            # ,'GoldsteinScale'
            ,
            "ActionGeo_CountryCode"
            # ,'SOURCEURL'           As we are going to agregate all these for a month, it is not relevant anymore to track it back
        ]
    ].copy()
    # Extract only root events as done in the paper
    df = df[df["IsRootEvent"] == 1]
    df = df.drop("IsRootEvent", axis=1)
    # Extract only the relevant events
    df = df[df["EventCode"].isin(CAMEOtags)]
    # drop NaNs, as they are mostly in the CountryCode
    df = df.dropna()
    df = df.reset_index(drop=True)
    df = df.rename(
        columns={
            "SQLDATE": "date",
            "EventCode": "code",
            "ActionGeo_CountryCode": "country",
        }
    )
    return df

# %%
def get_category_weights(eventdf, CAMEO_weights):
    """Get the aggregated weights for each of the 5 event categories for each country
    as described in the paper, for a day"""
    df = eventdf_FE(eventdf, CAMEO_weights.index.tolist())
    # Aggregate them by country and event-type-code
    # and get the quantity of the single event-types for in each country
    df = df.groupby(["country", "code"]).size()
    df = pd.DataFrame(df).reset_index().rename(columns={0: "count"})
    # Now we are associating each event-type to their corresponding
    # weights and labels describe in the CAMEO_weights reference table
    df["category"] = pd.NA
    for i, row in df.loc[:, ["code"]].iterrows():
        weight = CAMEO_weights.loc[row["code"]]["weight"]
        count = df["count"].iloc[i]
        df["count"].iloc[i] = count * weight / 3
        df["category"].iloc[i] = CAMEO_weights.loc[row["code"]]["label"]
    # Done this, we don't need the code column anymore
    # so we drop it, an agreggate by country and category
    df = df.drop("code", axis=1).groupby(["country", "category"]).sum()
    return df

# %%
def extract_csv_from_zip(url, target_folder):
    try:
        # Download the zip file
        zip_file_path = os.path.join(target_folder, "data.zip")
        urllib.request.urlretrieve(url, zip_file_path)

        # Extract the CSV file from the zip
        with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
            csv_filename = zip_ref.namelist()[0]  # Assuming only one file in the zip
            csv_file_path = os.path.join(target_folder, csv_filename)
            zip_ref.extract(csv_filename, target_folder)

        # Delete the zip file
        os.remove(zip_file_path)

        return csv_file_path

    except urllib.error.HTTPError as e:
        if e.code == 404:
            return None


def process_gdelt_data(
    start_date, end_date, target_folder, CAMEO_weights, header, verbose=False
):
    """This function:
    1.Scrapes the daily events-zip files from the GDELT web
    2.Extracts the csvs from the zips
    3.Filters, aggregates and preprocess the data in the csv's
    4.Leaves only the already preprocessed csv's in the hard disk
      ready to be aggregated per month so they can be added in the model
    """
    delta = timedelta(days=1)  # Increment of one day
    missing_dates = []

    while end_date >= start_date:
        sqldate = end_date.strftime("%Y%m%d")
        url = f"http://data.gdeltproject.org/events/{sqldate}.export.CSV.zip"
        csv_file_path = extract_csv_from_zip(url, target_folder)

        # Checking if its a missing date
        if csv_file_path == None:
            print(f"URL for SQLDATE {sqldate} does not exist. Skipping.")
            missing_dates.append(sqldate)
            end_date -= delta
            continue

        elif verbose:
            print(f"File for SQLDATE {sqldate} extracted successfully.")

        # Read CSV file into DataFrame
        df = pd.read_table(csv_file_path, names=header, dtype={"EventCode": str})

        # Process the DataFrame as needed
        df = get_category_weights(df, CAMEO_weights)

        # Save DataFrame as CSV
        output_csv_path = os.path.join(target_folder, f"{sqldate}.csv")
        df.to_csv(output_csv_path)

        # Delete the intermediate CSV file
        os.remove(csv_file_path)

        if verbose:
            print(f"Processed data saved as {output_csv_path}")

        end_date -= delta

    return missing_dates

# %%
header = "GLOBALEVENTID   SQLDATE MonthYear   Year    FractionDate	Actor1Code	Actor1Name	Actor1CountryCode	Actor1KnownGroupCode	Actor1EthnicCode	Actor1Religion1Code	Actor1Religion2Code	Actor1Type1Code	Actor1Type2Code	Actor1Type3Code	Actor2Code	Actor2Name	Actor2CountryCode	Actor2KnownGroupCode	Actor2EthnicCode	Actor2Religion1Code	Actor2Religion2Code	Actor2Type1Code	Actor2Type2Code	Actor2Type3Code	IsRootEvent	EventCode	EventBaseCode	EventRootCode	QuadClass	GoldsteinScale	NumMentions	NumSources	NumArticles	AvgTone	Actor1Geo_Type	Actor1Geo_FullName	Actor1Geo_CountryCode	Actor1Geo_ADM1Code	Actor1Geo_Lat	Actor1Geo_Long	Actor1Geo_FeatureID	Actor2Geo_Type	Actor2Geo_FullName	Actor2Geo_CountryCode	Actor2Geo_ADM1Code	Actor2Geo_Lat	Actor2Geo_Long	Actor2Geo_FeatureID	ActionGeo_Type	ActionGeo_FullName	ActionGeo_CountryCode	ActionGeo_ADM1Code	ActionGeo_Lat	ActionGeo_Long	ActionGeo_FeatureID	DATEADDED	SOURCEURL"
header = header.split()
CAMEO_weights = pd.read_csv(
    "../data/CAMEO_weights.csv", index_col=0, dtype={"code": str}
)
CAMEO_weights = CAMEO_weights.set_index("code").drop("description", axis=1)

# %%
start_date = datetime.strptime("20150101", "%Y%m%d")
# end_date = datetime.now() - timedelta(days=1)   # Uses the date of yesterday as the date
end_date = datetime.strptime("20160917", "%Y%m%d")
target_folder = "../data/gdelt_optimized/"
process_gdelt_data(
    start_date, end_date, target_folder, CAMEO_weights, header, verbose=False
)
# Out:
# []

# %% [markdown]
# URL for SQLDATE 20230323 does not exist. Skipping.
# URL for SQLDATE 20221110 does not exist. Skipping.

# %% [markdown]
# ### Past trials of the scrapping algorythms

# %%
def GDELTspiderV2(start_date, end_date, return_missing_dates=False, verbose=False):
    delta = timedelta(days=1)  # Increment of one day
    missing_dates = []

    while end_date >= start_date:
        sqldate = end_date.strftime("%Y%m%d")
        url = f"http://data.gdeltproject.org/events/{sqldate}.export.CSV.zip"
        directory = f"../data/gdelt_optimized/"
        zipfilepath = f"{directory}{sqldate}.export.CSV.zip"

        if not os.path.exists(zipfilepath):
            try:
                # Download the file
                urllib.request.urlretrieve(url, zipfilepath)
                if verbose:
                    print(f"File for SQLDATE {sqldate} downloaded successfully.")
                # Extracting the file
                with zipfile.ZipFile(zipfilepath, "r") as zip_ref:
                    zip_ref.extractall(directory)
                    if verbose:
                        print(f"{sqldate}.export.CSV extracted succesfully")
                    os.remove(zipfilepath)

            except urllib.error.HTTPError as e:
                if e.code == 404:
                    print(f"URL for SQLDATE {sqldate} does not exist. Skipping.")
                    missing_dates.append(sqldate)
        else:
            if verbose:
                print(f"File for SQLDATE {sqldate} already exists. Skipping.")
        end_date -= delta
    if return_missing_dates:
        return missing_dates

# %%
# start_date = datetime.strptime("20130401", "%Y%m%d")
start_date = datetime.strptime("20230501", "%Y%m%d")
end_date = datetime.now() - timedelta(days=1)  # Uses the date of yesterday as the date
GDELTspiderV2(start_date, end_date, return_missing_dates=True, verbose=True)
# Out:
# File for SQLDATE 20230515 downloaded successfully.
# 20230515.export.CSV extracted succesfully
# File for SQLDATE 20230514 downloaded successfully.
# 20230514.export.CSV extracted succesfully
# File for SQLDATE 20230513 downloaded successfully.
# 20230513.export.CSV extracted succesfully
# File for SQLDATE 20230512 downloaded successfully.
# 20230512.export.CSV extracted succesfully
# File for SQLDATE 20230511 downloaded successfully.
# 20230511.export.CSV extracted succesfully
# File for SQLDATE 20230510 downloaded successfully.
# 20230510.export.CSV extracted succesfully
# File for SQLDATE 20230509 downloaded successfully.
# 20230509.export.CSV extracted succesfully
# File for SQLDATE 20230508 downloaded successfully.
# 20230508.export.CSV extracted succesfully
# File for SQLDATE 20230507 downloaded successfully.
# 20230507.export.CSV extracted succesfully
# File for SQLDATE 20230506 downloaded successfully.
# 20230506.export.CSV extracted succesfully
# File for SQLDATE 20230505 downloaded successfully.
# 20230505.export.CSV extracted succesfully
# File for SQLDATE 20230504 downloaded successfully.
# 20230504.export.CSV extracted succesfully
# File for SQLDATE 20230503 downloaded successfully.
# 20230503.export.CSV extracted succesfully
# File for SQLDATE 20230502 downloaded successfully.
# 20230502.export.CSV extracted succesfully
# File for SQLDATE 20230501 downloaded successfully.
# 20230501.export.CSV extracted succesfully
# []

# %%
def GDELTspider(return_missing_dates=False, verbose=False):
    delta = timedelta(days=1)  # Increment of one day
    start_date = datetime.strptime("20130401", "%Y%m%d")
    end_date = datetime.now() - delta  # Uses the date of yesterday as the date
    missing_dates = []

    while end_date >= start_date:
        sqldate = end_date.strftime("%Y%m%d")
        url = f"http://data.gdeltproject.org/events/{sqldate}.export.CSV.zip"
        zipfilepath = f"../data/gdelt_data/zips/{sqldate}.export.CSV.zip"
        csvfilepath = f"../data/gdelt_data/extracted/{sqldate}.export.CSV"

        if not os.path.exists(csvfilepath):
            try:
                # Download the file
                urllib.request.urlretrieve(url, zipfilepath)
                if verbose:
                    print(f"File for SQLDATE {sqldate} downloaded successfully.")
            except urllib.error.HTTPError as e:
                if e.code == 404:
                    if verbose:
                        print(f"URL for SQLDATE {sqldate} does not exist. Skipping.")
                    missing_dates.append(sqldate)
        else:
            if verbose:
                print(f"File for SQLDATE {sqldate} already exists. Skipping.")
        end_date -= delta

    if return_missing_dates:
        return missing_dates

# %%
"""
Not running again for now, because there is no space left in the disk.
I should modify this scrappers in order to: 
1. download zip
2. extract csv
3. delete zip
4. Extract features from original csv
5. Save a new csv with the extracted features, reducted only for me relevant features.
6. delete original csv
"""

# %%
# Not run again until set modifiable dates, because the files are already extracted back until 20160101
# GDELTspider(verbose= True)

# %%
def GDELTextracter(verbose=False):
    delta = timedelta(days=1)  # Increment of one day
    start_date = datetime.strptime("20130401", "%Y%m%d")
    end_date = datetime.now() - delta  # Uses the date of yesterday as the date

    while end_date >= start_date:
        sqldate = end_date.strftime("%Y%m%d")
        csvpath = f"../data/gdelt_data/extracted/"
        csvfile = f"{csvpath}{sqldate}.export.CSV"
        zipfilepath = f"../data/gdelt_data/zips/{sqldate}.export.CSV.zip"

        if not os.path.exists(csvfile):
            if os.path.exists(zipfilepath):
                with zipfile.ZipFile(zipfilepath, "r") as zip_ref:
                    zip_ref.extractall(csvpath)
                    if verbose:
                        print(f"{sqldate}.export.CSV extracted succesfully")
            else:
                if verbose:
                    print(f"{sqldate}.export.CSV.zip doesnt exists")
        else:
            if verbose:
                print(f"{sqldate}.export.CSV already exists")
        end_date -= delta

# %%
# GDELTextracter(verbose= True)
# Out:
# 20230511.export.CSV already exists
# 20230510.export.CSV already exists
# 20230509.export.CSV already exists
# 20230508.export.CSV already exists
# 20230507.export.CSV already exists
# 20230506.export.CSV already exists
# 20230505.export.CSV already exists
# 20230504.export.CSV already exists
# 20230503.export.CSV already exists
# 20230502.export.CSV already exists
# 20230501.export.CSV already exists
# 20230430.export.CSV already exists
# 20230429.export.CSV already exists
# 20230428.export.CSV already exists
# 20230427.export.CSV already exists
# 20230426.export.CSV already exists
# 20230425.export.CSV already exists
# 20230424.export.CSV already exists
# 20230423.export.CSV already exists
# 20230422.export.CSV already exists
# 20230421.export.CSV already exists
# 20230420.export.CSV already exists
# 20230419.export.CSV already exists
# 20230418.export.CSV already exists
# 20230417.export.CSV already exists
# 20230416.export.CSV already exists
# 20230415.export.CSV already exists
# 20230414.export.CSV already exists
# 20230413.export.CSV already exists
# 20230412.export.CSV already exists
# 20230411.export.CSV already exists
# 20230410.export.CSV already exists
# 20230409.export.CSV already exists
# 20230408.export.CSV already exists
# 20230407.export.CSV already exists
# 20230406.export.CSV already exists
# 20230405.export.CSV already exists
# 20230404.export.CSV already exists
# 20230403.export.CSV already exists
# 20230402.export.CSV already exists
# 20230401.export.CSV already exists
# 20230331.export.CSV already exists
# 20230330.export.CSV already exists
# 20230329.export.CSV already exists
# 20230328.export.CSV already exists
# 20230327.export.CSV already exists
# 20230326.export.CSV already exists
# 20230325.export.CSV already exists
# 20230324.export.CSV already exists
# 20230323.export.CSV.zip doesnt exists
# 20230322.export.CSV already exists
# 20230321.export.CSV already exists
# 20230320.export.CSV already exists
# 20230319.export.CSV already exists
# 20230318.export.CSV already exists
# 20230317.export.CSV already exists
# 20230316.export.CSV already exists
# 20230315.export.CSV already exists
# 20230314.export.CSV already exists
# 20230313.export.CSV already exists
# 20230312.export.CSV already exists
# 20230311.export.CSV already exists
# 20230310.export.CSV already exists
# 20230309.export.CSV already exists
# 20230308.export.CSV already exists
# 20230307.export.CSV already exists
# 20230306.export.CSV already exists
# 20230305.export.CSV already exists
# 20230304.export.CSV already exists
# 20230303.export.CSV already exists
# 20230302.export.CSV already exists
# 20230301.export.CSV already exists
# 20230228.export.CSV already exists
# 20230227.export.CSV already exists
# 20230226.export.CSV already exists
# 20230225.export.CSV already exists
# 20230224.export.CSV already exists
# 20230223.export.CSV already exists
# 20230222.export.CSV already exists
# 20230221.export.CSV already exists
# 20230220.export.CSV already exists
# 20230219.export.CSV already exists
# 20230218.export.CSV already exists
# 20230217.export.CSV already exists
# 20230216.export.CSV already exists
# 20230215.export.CSV already exists
# 20230214.export.CSV already exists
# 20230213.export.CSV already exists
# 20230212.export.CSV already exists
# 20230211.export.CSV already exists
# 20230210.export.CSV already exists
# 20230209.export.CSV already exists
# 20230208.export.CSV already exists
# 20230207.export.CSV already exists
# 20230206.export.CSV already exists
# 20230205.export.CSV already exists
# 20230204.export.CSV already exists
# 20230203.export.CSV already exists
# 20230202.export.CSV already exists
# 20230201.export.CSV already exists
# 20230131.export.CSV already exists
# 20230130.export.CSV already exists
# 20230129.export.CSV already exists
# 20230128.export.CSV already exists
# 20230127.export.CSV already exists
# 20230126.export.CSV already exists
# 20230125.export.CSV already exists
# 20230124.export.CSV already exists
# 20230123.export.CSV already exists
# 20230122.export.CSV already exists
# 20230121.export.CSV already exists
# 20230120.export.CSV already exists
# 20230119.export.CSV already exists
# 20230118.export.CSV already exists
# 20230117.export.CSV already exists
# 20230116.export.CSV already exists
# 20230115.export.CSV already exists
# 20230114.export.CSV already exists
# 20230113.export.CSV already exists
# 20230112.export.CSV already exists
# 20230111.export.CSV already exists
# 20230110.export.CSV already exists
# 20230109.export.CSV already exists
# 20230108.export.CSV already exists
# 20230107.export.CSV already exists
# 20230106.export.CSV already exists
# 20230105.export.CSV already exists
# 20230104.export.CSV already exists
# 20230103.export.CSV already exists
# 20230102.export.CSV already exists
# 20230101.export.CSV already exists
# 20221231.export.CSV already exists
# 20221230.export.CSV already exists
# 20221229.export.CSV already exists
# 20221228.export.CSV already exists
# 20221227.export.CSV already exists
# 20221226.export.CSV already exists
# 20221225.export.CSV already exists
# 20221224.export.CSV already exists
# 20221223.export.CSV already exists
# 20221222.export.CSV already exists
# 20221221.export.CSV already exists
# 20221220.export.CSV already exists
# 20221219.export.CSV already exists
# 20221218.export.CSV already exists
# 20221217.export.CSV already exists
# 20221216.export.CSV already exists
# 20221215.export.CSV already exists
# 20221214.export.CSV already exists
# 20221213.export.CSV already exists
# 20221212.export.CSV already exists
# 20221211.export.CSV already exists
# 20221210.export.CSV already exists
# 20221209.export.CSV already exists
# 20221208.export.CSV already exists
# 20221207.export.CSV already exists
# 20221206.export.CSV already exists
# 20221205.export.CSV already exists
# 20221204.export.CSV already exists
# 20221203.export.CSV already exists
# 20221202.export.CSV already exists
# 20221201.export.CSV already exists
# 20221130.export.CSV already exists
# 20221129.export.CSV already exists
# 20221128.export.CSV already exists
# 20221127.export.CSV already exists
# 20221126.export.CSV already exists
# 20221125.export.CSV already exists
# 20221124.export.CSV already exists
# 20221123.export.CSV already exists
# 20221122.export.CSV already exists
# 20221121.export.CSV already exists
# 20221120.export.CSV already exists
# 20221119.export.CSV already exists
# 20221118.export.CSV already exists
# 20221117.export.CSV already exists
# 20221116.export.CSV already exists
# 20221115.export.CSV already exists
# 20221114.export.CSV already exists
# 20221113.export.CSV already exists
# 20221112.export.CSV already exists
# 20221111.export.CSV already exists
# 20221110.export.CSV.zip doesnt exists
# 20221109.export.CSV already exists
# 20221108.export.CSV already exists
# 20221107.export.CSV already exists
# 20221106.export.CSV already exists
# 20221105.export.CSV already exists
# 20221104.export.CSV already exists
# 20221103.export.CSV already exists
# 20221102.export.CSV already exists
# 20221101.export.CSV already exists
# 20221031.export.CSV already exists
# 20221030.export.CSV already exists
# 20221029.export.CSV already exists
# 20221028.export.CSV already exists
# 20221027.export.CSV already exists
# 20221026.export.CSV already exists
# 20221025.export.CSV already exists
# 20221024.export.CSV already exists
# 20221023.export.CSV already exists
# 20221022.export.CSV already exists
# 20221021.export.CSV already exists
# 20221020.export.CSV already exists
# 20221019.export.CSV already exists
# 20221018.export.CSV already exists
# 20221017.export.CSV already exists
# 20221016.export.CSV already exists
# 20221015.export.CSV already exists
# 20221014.export.CSV already exists
# 20221013.export.CSV already exists
# 20221012.export.CSV already exists
# 20221011.export.CSV already exists
# 20221010.export.CSV already exists
# 20221009.export.CSV already exists
# 20221008.export.CSV already exists
# 20221007.export.CSV already exists
# 20221006.export.CSV already exists
# 20221005.export.CSV already exists
# 20221004.export.CSV already exists
# 20221003.export.CSV already exists
# 20221002.export.CSV already exists
# 20221001.export.CSV already exists
# 20220930.export.CSV already exists
# 20220929.export.CSV already exists
# 20220928.export.CSV already exists
# 20220927.export.CSV already exists
# 20220926.export.CSV already exists
# 20220925.export.CSV already exists
# 20220924.export.CSV already exists
# 20220923.export.CSV already exists
# 20220922.export.CSV already exists
# 20220921.export.CSV already exists
# 20220920.export.CSV already exists
# 20220919.export.CSV already exists
# 20220918.export.CSV already exists
# 20220917.export.CSV already exists
# 20220916.export.CSV already exists
# 20220915.export.CSV already exists
# 20220914.export.CSV already exists
# 20220913.export.CSV already exists
# 20220912.export.CSV already exists
# 20220911.export.CSV already exists
# 20220910.export.CSV already exists
# 20220909.export.CSV already exists
# 20220908.export.CSV already exists
# 20220907.export.CSV already exists
# 20220906.export.CSV already exists
# 20220905.export.CSV already exists
# 20220904.export.CSV already exists
# 20220903.export.CSV already exists
# 20220902.export.CSV already exists
# 20220901.export.CSV already exists
# 20220831.export.CSV already exists
# 20220830.export.CSV already exists
# 20220829.export.CSV already exists
# 20220828.export.CSV already exists
# 20220827.export.CSV already exists
# 20220826.export.CSV already exists
# 20220825.export.CSV already exists
# 20220824.export.CSV already exists
# 20220823.export.CSV already exists
# 20220822.export.CSV already exists
# 20220821.export.CSV already exists
# 20220820.export.CSV already exists
# 20220819.export.CSV already exists
# 20220818.export.CSV already exists
# 20220817.export.CSV already exists
# 20220816.export.CSV already exists
# 20220815.export.CSV already exists
# 20220814.export.CSV already exists
# 20220813.export.CSV already exists
# 20220812.export.CSV already exists
# 20220811.export.CSV already exists
# 20220810.export.CSV already exists
# 20220809.export.CSV already exists
# 20220808.export.CSV already exists
# 20220807.export.CSV already exists
# 20220806.export.CSV already exists
# 20220805.export.CSV already exists
# 20220804.export.CSV already exists
# 20220803.export.CSV already exists
# 20220802.export.CSV already exists
# 20220801.export.CSV already exists
# 20220731.export.CSV already exists
# 20220730.export.CSV already exists
# 20220729.export.CSV already exists
# 20220728.export.CSV already exists
# 20220727.export.CSV already exists
# 20220726.export.CSV already exists
# 20220725.export.CSV already exists
# 20220724.export.CSV already exists
# 20220723.export.CSV already exists
# 20220722.export.CSV already exists
# 20220721.export.CSV already exists
# 20220720.export.CSV already exists
# 20220719.export.CSV already exists
# 20220718.export.CSV already exists
# 20220717.export.CSV already exists
# 20220716.export.CSV already exists
# 20220715.export.CSV already exists
# 20220714.export.CSV already exists
# 20220713.export.CSV already exists
# 20220712.export.CSV already exists
# 20220711.export.CSV already exists
# 20220710.export.CSV already exists
# 20220709.export.CSV already exists
# 20220708.export.CSV already exists
# 20220707.export.CSV already exists
# 20220706.export.CSV already exists
# 20220705.export.CSV already exists
# 20220704.export.CSV already exists
# 20220703.export.CSV already exists
# 20220702.export.CSV already exists
# 20220701.export.CSV already exists
# 20220630.export.CSV already exists
# 20220629.export.CSV already exists
# 20220628.export.CSV already exists
# 20220627.export.CSV already exists
# 20220626.export.CSV already exists
# 20220625.export.CSV already exists
# 20220624.export.CSV already exists
# 20220623.export.CSV already exists
# 20220622.export.CSV already exists
# 20220621.export.CSV already exists
# 20220620.export.CSV already exists
# 20220619.export.CSV already exists
# 20220618.export.CSV already exists
# 20220617.export.CSV already exists
# 20220616.export.CSV already exists
# 20220615.export.CSV already exists
# 20220614.export.CSV already exists
# 20220613.export.CSV already exists
# 20220612.export.CSV already exists
# 20220611.export.CSV already exists
# 20220610.export.CSV already exists
# 20220609.export.CSV already exists
# 20220608.export.CSV already exists
# 20220607.export.CSV already exists
# 20220606.export.CSV already exists
# 20220605.export.CSV already exists
# 20220604.export.CSV already exists
# 20220603.export.CSV already exists
# 20220602.export.CSV already exists
# 20220601.export.CSV already exists
# 20220531.export.CSV already exists
# 20220530.export.CSV already exists
# 20220529.export.CSV already exists
# 20220528.export.CSV already exists
# 20220527.export.CSV already exists
# 20220526.export.CSV already exists
# 20220525.export.CSV already exists
# 20220524.export.CSV already exists
# 20220523.export.CSV already exists
# 20220522.export.CSV already exists
# 20220521.export.CSV already exists
# 20220520.export.CSV already exists
# 20220519.export.CSV already exists
# 20220518.export.CSV already exists
# 20220517.export.CSV already exists
# 20220516.export.CSV already exists
# 20220515.export.CSV already exists
# 20220514.export.CSV already exists
# 20220513.export.CSV already exists
# 20220512.export.CSV already exists
# 20220511.export.CSV already exists
# 20220510.export.CSV already exists
# 20220509.export.CSV already exists
# 20220508.export.CSV already exists
# 20220507.export.CSV already exists
# 20220506.export.CSV already exists
# 20220505.export.CSV already exists
# 20220504.export.CSV already exists
# 20220503.export.CSV already exists
# 20220502.export.CSV already exists
# 20220501.export.CSV already exists
# 20220430.export.CSV already exists
# 20220429.export.CSV already exists
# 20220428.export.CSV already exists
# 20220427.export.CSV already exists
# 20220426.export.CSV already exists
# 20220425.export.CSV already exists
# 20220424.export.CSV already exists
# 20220423.export.CSV already exists
# 20220422.export.CSV already exists
# 20220421.export.CSV already exists
# 20220420.export.CSV already exists
# 20220419.export.CSV already exists
# 20220418.export.CSV already exists
# 20220417.export.CSV already exists
# 20220416.export.CSV already exists
# 20220415.export.CSV already exists
# 20220414.export.CSV already exists
# 20220413.export.CSV already exists
# 20220412.export.CSV already exists
# 20220411.export.CSV already exists
# 20220410.export.CSV already exists
# 20220409.export.CSV already exists
# 20220408.export.CSV already exists
# 20220407.export.CSV already exists
# 20220406.export.CSV already exists
# 20220405.export.CSV already exists
# 20220404.export.CSV already exists
# 20220403.export.CSV already exists
# 20220402.export.CSV already exists
# 20220401.export.CSV already exists
# 20220331.export.CSV already exists
# 20220330.export.CSV already exists
# 20220329.export.CSV already exists
# 20220328.export.CSV already exists
# 20220327.export.CSV already exists
# 20220326.export.CSV already exists
# 20220325.export.CSV already exists
# 20220324.export.CSV already exists
# 20220323.export.CSV already exists
# 20220322.export.CSV already exists
# 20220321.export.CSV already exists
# 20220320.export.CSV already exists
# 20220319.export.CSV already exists
# 20220318.export.CSV already exists
# 20220317.export.CSV already exists
# 20220316.export.CSV already exists
# 20220315.export.CSV already exists
# 20220314.export.CSV already exists
# 20220313.export.CSV already exists
# 20220312.export.CSV already exists
# 20220311.export.CSV already exists
# 20220310.export.CSV already exists
# 20220309.export.CSV already exists
# 20220308.export.CSV already exists
# 20220307.export.CSV already exists
# 20220306.export.CSV already exists
# 20220305.export.CSV already exists
# 20220304.export.CSV already exists
# 20220303.export.CSV already exists
# 20220302.export.CSV already exists
# 20220301.export.CSV already exists
# 20220228.export.CSV already exists
# 20220227.export.CSV already exists
# 20220226.export.CSV already exists
# 20220225.export.CSV already exists
# 20220224.export.CSV already exists
# 20220223.export.CSV already exists
# 20220222.export.CSV already exists
# 20220221.export.CSV already exists
# 20220220.export.CSV already exists
# 20220219.export.CSV already exists
# 20220218.export.CSV already exists
# 20220217.export.CSV already exists
# 20220216.export.CSV already exists
# 20220215.export.CSV already exists
# 20220214.export.CSV already exists
# 20220213.export.CSV already exists
# 20220212.export.CSV already exists
# 20220211.export.CSV already exists
# 20220210.export.CSV already exists
# 20220209.export.CSV already exists
# 20220208.export.CSV already exists
# 20220207.export.CSV already exists
# 20220206.export.CSV already exists
# 20220205.export.CSV already exists
# 20220204.export.CSV already exists
# 20220203.export.CSV already exists
# 20220202.export.CSV already exists
# 20220201.export.CSV already exists
# 20220131.export.CSV already exists
# 20220130.export.CSV already exists
# 20220129.export.CSV already exists
# 20220128.export.CSV already exists
# 20220127.export.CSV already exists
# 20220126.export.CSV already exists
# 20220125.export.CSV already exists
# 20220124.export.CSV already exists
# 20220123.export.CSV already exists
# 20220122.export.CSV already exists
# 20220121.export.CSV already exists
# 20220120.export.CSV already exists
# 20220119.export.CSV already exists
# 20220118.export.CSV already exists
# 20220117.export.CSV already exists
# 20220116.export.CSV already exists
# 20220115.export.CSV already exists
# 20220114.export.CSV already exists
# 20220113.export.CSV already exists
# 20220112.export.CSV already exists
# 20220111.export.CSV already exists
# 20220110.export.CSV already exists
# 20220109.export.CSV already exists
# 20220108.export.CSV already exists
# 20220107.export.CSV already exists
# 20220106.export.CSV already exists
# 20220105.export.CSV already exists
# 20220104.export.CSV already exists
# 20220103.export.CSV already exists
# 20220102.export.CSV already exists
# 20220101.export.CSV already exists
# 20211231.export.CSV already exists
# 20211230.export.CSV already exists
# 20211229.export.CSV already exists
# 20211228.export.CSV already exists
# 20211227.export.CSV already exists
# 20211226.export.CSV already exists
# 20211225.export.CSV already exists
# 20211224.export.CSV already exists
# 20211223.export.CSV already exists
# 20211222.export.CSV already exists
# 20211221.export.CSV already exists
# 20211220.export.CSV already exists
# 20211219.export.CSV already exists
# 20211218.export.CSV already exists
# 20211217.export.CSV already exists
# 20211216.export.CSV already exists
# 20211215.export.CSV already exists
# 20211214.export.CSV already exists
# 20211213.export.CSV already exists
# 20211212.export.CSV already exists
# 20211211.export.CSV already exists
# 20211210.export.CSV already exists
# 20211209.export.CSV already exists
# 20211208.export.CSV already exists
# 20211207.export.CSV already exists
# 20211206.export.CSV already exists
# 20211205.export.CSV already exists
# 20211204.export.CSV already exists
# 20211203.export.CSV already exists
# 20211202.export.CSV already exists
# 20211201.export.CSV already exists
# 20211130.export.CSV already exists
# 20211129.export.CSV already exists
# 20211128.export.CSV already exists
# 20211127.export.CSV already exists
# 20211126.export.CSV already exists
# 20211125.export.CSV already exists
# 20211124.export.CSV already exists
# 20211123.export.CSV already exists
# 20211122.export.CSV already exists
# 20211121.export.CSV already exists
# 20211120.export.CSV already exists
# 20211119.export.CSV already exists
# 20211118.export.CSV already exists
# 20211117.export.CSV already exists
# 20211116.export.CSV already exists
# 20211115.export.CSV already exists
# 20211114.export.CSV already exists
# 20211113.export.CSV already exists
# 20211112.export.CSV already exists
# 20211111.export.CSV already exists
# 20211110.export.CSV already exists
# 20211109.export.CSV already exists
# 20211108.export.CSV already exists
# 20211107.export.CSV already exists
# 20211106.export.CSV already exists
# 20211105.export.CSV already exists
# 20211104.export.CSV already exists
# 20211103.export.CSV already exists
# 20211102.export.CSV already exists
# 20211101.export.CSV already exists
# 20211031.export.CSV already exists
# 20211030.export.CSV already exists
# 20211029.export.CSV already exists
# 20211028.export.CSV already exists
# 20211027.export.CSV already exists
# 20211026.export.CSV already exists
# 20211025.export.CSV already exists
# 20211024.export.CSV already exists
# 20211023.export.CSV already exists
# 20211022.export.CSV already exists
# 20211021.export.CSV already exists
# 20211020.export.CSV already exists
# 20211019.export.CSV already exists
# 20211018.export.CSV already exists
# 20211017.export.CSV already exists
# 20211016.export.CSV already exists
# 20211015.export.CSV already exists
# 20211014.export.CSV already exists
# 20211013.export.CSV already exists
# 20211012.export.CSV already exists
# 20211011.export.CSV already exists
# 20211010.export.CSV already exists
# 20211009.export.CSV already exists
# 20211008.export.CSV already exists
# 20211007.export.CSV already exists
# 20211006.export.CSV already exists
# 20211005.export.CSV already exists
# 20211004.export.CSV already exists
# 20211003.export.CSV already exists
# 20211002.export.CSV already exists
# 20211001.export.CSV already exists
# 20210930.export.CSV already exists
# 20210929.export.CSV already exists
# 20210928.export.CSV already exists
# 20210927.export.CSV already exists
# 20210926.export.CSV already exists
# 20210925.export.CSV already exists
# 20210924.export.CSV already exists
# 20210923.export.CSV already exists
# 20210922.export.CSV already exists
# 20210921.export.CSV already exists
# 20210920.export.CSV already exists
# 20210919.export.CSV already exists
# 20210918.export.CSV already exists
# 20210917.export.CSV already exists
# 20210916.export.CSV already exists
# 20210915.export.CSV already exists
# 20210914.export.CSV already exists
# 20210913.export.CSV already exists
# 20210912.export.CSV already exists
# 20210911.export.CSV already exists
# 20210910.export.CSV already exists
# 20210909.export.CSV already exists
# 20210908.export.CSV already exists
# 20210907.export.CSV already exists
# 20210906.export.CSV already exists
# 20210905.export.CSV already exists
# 20210904.export.CSV already exists
# 20210903.export.CSV already exists
# 20210902.export.CSV already exists
# 20210901.export.CSV already exists
# 20210831.export.CSV already exists
# 20210830.export.CSV already exists
# 20210829.export.CSV already exists
# 20210828.export.CSV already exists
# 20210827.export.CSV already exists
# 20210826.export.CSV already exists
# 20210825.export.CSV already exists
# 20210824.export.CSV already exists
# 20210823.export.CSV already exists
# 20210822.export.CSV already exists
# 20210821.export.CSV already exists
# 20210820.export.CSV already exists
# 20210819.export.CSV already exists
# 20210818.export.CSV already exists
# 20210817.export.CSV already exists
# 20210816.export.CSV already exists
# 20210815.export.CSV already exists
# 20210814.export.CSV already exists
# 20210813.export.CSV already exists
# 20210812.export.CSV already exists
# 20210811.export.CSV already exists
# 20210810.export.CSV already exists
# 20210809.export.CSV already exists
# 20210808.export.CSV already exists
# 20210807.export.CSV already exists
# 20210806.export.CSV already exists
# 20210805.export.CSV already exists
# 20210804.export.CSV already exists
# 20210803.export.CSV already exists
# 20210802.export.CSV already exists
# 20210801.export.CSV already exists
# 20210731.export.CSV already exists
# 20210730.export.CSV already exists
# 20210729.export.CSV already exists
# 20210728.export.CSV already exists
# 20210727.export.CSV already exists
# 20210726.export.CSV already exists
# 20210725.export.CSV already exists
# 20210724.export.CSV already exists
# 20210723.export.CSV already exists
# 20210722.export.CSV already exists
# 20210721.export.CSV already exists
# 20210720.export.CSV already exists
# 20210719.export.CSV already exists
# 20210718.export.CSV already exists
# 20210717.export.CSV already exists
# 20210716.export.CSV already exists
# 20210715.export.CSV already exists
# 20210714.export.CSV already exists
# 20210713.export.CSV already exists
# 20210712.export.CSV already exists
# 20210711.export.CSV already exists
# 20210710.export.CSV already exists
# 20210709.export.CSV already exists
# 20210708.export.CSV already exists
# 20210707.export.CSV already exists
# 20210706.export.CSV already exists
# 20210705.export.CSV already exists
# 20210704.export.CSV already exists
# 20210703.export.CSV already exists
# 20210702.export.CSV already exists
# 20210701.export.CSV already exists
# 20210630.export.CSV already exists
# 20210629.export.CSV already exists
# 20210628.export.CSV already exists
# 20210627.export.CSV already exists
# 20210626.export.CSV already exists
# 20210625.export.CSV already exists
# 20210624.export.CSV already exists
# 20210623.export.CSV already exists
# 20210622.export.CSV already exists
# 20210621.export.CSV already exists
# 20210620.export.CSV already exists
# 20210619.export.CSV already exists
# 20210618.export.CSV already exists
# 20210617.export.CSV already exists
# 20210616.export.CSV already exists
# 20210615.export.CSV already exists
# 20210614.export.CSV already exists
# 20210613.export.CSV already exists
# 20210612.export.CSV already exists
# 20210611.export.CSV already exists
# 20210610.export.CSV already exists
# 20210609.export.CSV already exists
# 20210608.export.CSV already exists
# 20210607.export.CSV already exists
# 20210606.export.CSV already exists
# 20210605.export.CSV already exists
# 20210604.export.CSV already exists
# 20210603.export.CSV already exists
# 20210602.export.CSV already exists
# 20210601.export.CSV already exists
# 20210531.export.CSV already exists
# 20210530.export.CSV already exists
# 20210529.export.CSV already exists
# 20210528.export.CSV already exists
# 20210527.export.CSV already exists
# 20210526.export.CSV already exists
# 20210525.export.CSV already exists
# 20210524.export.CSV already exists
# 20210523.export.CSV already exists
# 20210522.export.CSV already exists
# 20210521.export.CSV already exists
# 20210520.export.CSV already exists
# 20210519.export.CSV already exists
# 20210518.export.CSV already exists
# 20210517.export.CSV already exists
# 20210516.export.CSV already exists
# 20210515.export.CSV already exists
# 20210514.export.CSV already exists
# 20210513.export.CSV already exists
# 20210512.export.CSV already exists
# 20210511.export.CSV already exists
# 20210510.export.CSV already exists
# 20210509.export.CSV already exists
# 20210508.export.CSV already exists
# 20210507.export.CSV already exists
# 20210506.export.CSV already exists
# 20210505.export.CSV already exists
# 20210504.export.CSV already exists
# 20210503.export.CSV already exists
# 20210502.export.CSV already exists
# 20210501.export.CSV already exists
# 20210430.export.CSV already exists
# 20210429.export.CSV already exists
# 20210428.export.CSV already exists
# 20210427.export.CSV already exists
# 20210426.export.CSV already exists
# 20210425.export.CSV already exists
# 20210424.export.CSV already exists
# 20210423.export.CSV already exists
# 20210422.export.CSV already exists
# 20210421.export.CSV already exists
# 20210420.export.CSV already exists
# 20210419.export.CSV already exists
# 20210418.export.CSV already exists
# 20210417.export.CSV already exists
# 20210416.export.CSV already exists
# 20210415.export.CSV already exists
# 20210414.export.CSV already exists
# 20210413.export.CSV already exists
# 20210412.export.CSV already exists
# 20210411.export.CSV already exists
# 20210410.export.CSV already exists
# 20210409.export.CSV already exists
# 20210408.export.CSV already exists
# 20210407.export.CSV already exists
# 20210406.export.CSV already exists
# 20210405.export.CSV already exists
# 20210404.export.CSV already exists
# 20210403.export.CSV already exists
# 20210402.export.CSV already exists
# 20210401.export.CSV already exists
# 20210331.export.CSV already exists
# 20210330.export.CSV already exists
# 20210329.export.CSV already exists
# 20210328.export.CSV already exists
# 20210327.export.CSV already exists
# 20210326.export.CSV already exists
# 20210325.export.CSV already exists
# 20210324.export.CSV already exists
# 20210323.export.CSV already exists
# 20210322.export.CSV already exists
# 20210321.export.CSV already exists
# 20210320.export.CSV already exists
# 20210319.export.CSV already exists
# 20210318.export.CSV already exists
# 20210317.export.CSV already exists
# 20210316.export.CSV already exists
# 20210315.export.CSV already exists
# 20210314.export.CSV already exists
# 20210313.export.CSV already exists
# 20210312.export.CSV already exists
# 20210311.export.CSV already exists
# 20210310.export.CSV already exists
# 20210309.export.CSV already exists
# 20210308.export.CSV already exists
# 20210307.export.CSV already exists
# 20210306.export.CSV already exists
# 20210305.export.CSV already exists
# 20210304.export.CSV already exists
# 20210303.export.CSV already exists
# 20210302.export.CSV already exists
# 20210301.export.CSV already exists
# 20210228.export.CSV already exists
# 20210227.export.CSV already exists
# 20210226.export.CSV already exists
# 20210225.export.CSV already exists
# 20210224.export.CSV already exists
# 20210223.export.CSV already exists
# 20210222.export.CSV already exists
# 20210221.export.CSV already exists
# 20210220.export.CSV already exists
# 20210219.export.CSV already exists
# 20210218.export.CSV already exists
# 20210217.export.CSV already exists
# 20210216.export.CSV already exists
# 20210215.export.CSV already exists
# 20210214.export.CSV already exists
# 20210213.export.CSV already exists
# 20210212.export.CSV already exists
# 20210211.export.CSV already exists
# 20210210.export.CSV already exists
# 20210209.export.CSV already exists
# 20210208.export.CSV already exists
# 20210207.export.CSV already exists
# 20210206.export.CSV already exists
# 20210205.export.CSV already exists
# 20210204.export.CSV already exists
# 20210203.export.CSV already exists
# 20210202.export.CSV already exists
# 20210201.export.CSV already exists
# 20210131.export.CSV already exists
# 20210130.export.CSV already exists
# 20210129.export.CSV already exists
# 20210128.export.CSV already exists
# 20210127.export.CSV already exists
# 20210126.export.CSV already exists
# 20210125.export.CSV already exists
# 20210124.export.CSV already exists
# 20210123.export.CSV already exists
# 20210122.export.CSV already exists
# 20210121.export.CSV already exists
# 20210120.export.CSV already exists
# 20210119.export.CSV already exists
# 20210118.export.CSV already exists
# 20210117.export.CSV already exists
# 20210116.export.CSV already exists
# 20210115.export.CSV already exists
# 20210114.export.CSV already exists
# 20210113.export.CSV already exists
# 20210112.export.CSV already exists
# 20210111.export.CSV already exists
# 20210110.export.CSV already exists
# 20210109.export.CSV already exists
# 20210108.export.CSV already exists
# 20210107.export.CSV already exists
# 20210106.export.CSV already exists
# 20210105.export.CSV already exists
# 20210104.export.CSV already exists
# 20210103.export.CSV already exists
# 20210102.export.CSV already exists
# 20210101.export.CSV already exists
# 20201231.export.CSV already exists
# 20201230.export.CSV already exists
# 20201229.export.CSV already exists
# 20201228.export.CSV already exists
# 20201227.export.CSV already exists
# 20201226.export.CSV already exists
# 20201225.export.CSV already exists
# 20201224.export.CSV already exists
# 20201223.export.CSV already exists
# 20201222.export.CSV already exists
# 20201221.export.CSV already exists
# 20201220.export.CSV already exists
# 20201219.export.CSV already exists
# 20201218.export.CSV already exists
# 20201217.export.CSV already exists
# 20201216.export.CSV already exists
# 20201215.export.CSV already exists
# 20201214.export.CSV already exists
# 20201213.export.CSV already exists
# 20201212.export.CSV already exists
# 20201211.export.CSV already exists
# 20201210.export.CSV already exists
# 20201209.export.CSV already exists
# 20201208.export.CSV already exists
# 20201207.export.CSV already exists
# 20201206.export.CSV already exists
# 20201205.export.CSV already exists
# 20201204.export.CSV already exists
# 20201203.export.CSV already exists
# 20201202.export.CSV already exists
# 20201201.export.CSV already exists
# 20201130.export.CSV already exists
# 20201129.export.CSV already exists
# 20201128.export.CSV already exists
# 20201127.export.CSV already exists
# 20201126.export.CSV already exists
# 20201125.export.CSV already exists
# 20201124.export.CSV already exists
# 20201123.export.CSV already exists
# 20201122.export.CSV already exists
# 20201121.export.CSV already exists
# 20201120.export.CSV already exists
# 20201119.export.CSV already exists
# 20201118.export.CSV already exists
# 20201117.export.CSV already exists
# 20201116.export.CSV already exists
# 20201115.export.CSV already exists
# 20201114.export.CSV already exists
# 20201113.export.CSV already exists
# 20201112.export.CSV already exists
# 20201111.export.CSV already exists
# 20201110.export.CSV already exists
# 20201109.export.CSV already exists
# 20201108.export.CSV already exists
# 20201107.export.CSV already exists
# 20201106.export.CSV already exists
# 20201105.export.CSV already exists
# 20201104.export.CSV already exists
# 20201103.export.CSV already exists
# 20201102.export.CSV already exists
# 20201101.export.CSV already exists
# 20201031.export.CSV already exists
# 20201030.export.CSV already exists
# 20201029.export.CSV already exists
# 20201028.export.CSV already exists
# 20201027.export.CSV already exists
# 20201026.export.CSV already exists
# 20201025.export.CSV already exists
# 20201024.export.CSV already exists
# 20201023.export.CSV already exists
# 20201022.export.CSV already exists
# 20201021.export.CSV already exists
# 20201020.export.CSV already exists
# 20201019.export.CSV already exists
# 20201018.export.CSV already exists
# 20201017.export.CSV already exists
# 20201016.export.CSV already exists
# 20201015.export.CSV already exists
# 20201014.export.CSV already exists
# 20201013.export.CSV already exists
# 20201012.export.CSV already exists
# 20201011.export.CSV already exists
# 20201010.export.CSV already exists
# 20201009.export.CSV already exists
# 20201008.export.CSV already exists
# 20201007.export.CSV already exists
# 20201006.export.CSV already exists
# 20201005.export.CSV already exists
# 20201004.export.CSV already exists
# 20201003.export.CSV already exists
# 20201002.export.CSV already exists
# 20201001.export.CSV already exists
# 20200930.export.CSV already exists
# 20200929.export.CSV already exists
# 20200928.export.CSV already exists
# 20200927.export.CSV already exists
# 20200926.export.CSV already exists
# 20200925.export.CSV already exists
# 20200924.export.CSV already exists
# 20200923.export.CSV already exists
# 20200922.export.CSV already exists
# 20200921.export.CSV already exists
# 20200920.export.CSV already exists
# 20200919.export.CSV already exists
# 20200918.export.CSV already exists
# 20200917.export.CSV already exists
# 20200916.export.CSV already exists
# 20200915.export.CSV already exists
# 20200914.export.CSV already exists
# 20200913.export.CSV already exists
# 20200912.export.CSV already exists
# 20200911.export.CSV already exists
# 20200910.export.CSV already exists
# 20200909.export.CSV already exists
# 20200908.export.CSV already exists
# 20200907.export.CSV already exists
# 20200906.export.CSV already exists
# 20200905.export.CSV already exists
# 20200904.export.CSV already exists
# 20200903.export.CSV already exists
# 20200902.export.CSV already exists
# 20200901.export.CSV already exists
# 20200831.export.CSV already exists
# 20200830.export.CSV already exists
# 20200829.export.CSV already exists
# 20200828.export.CSV already exists
# 20200827.export.CSV already exists
# 20200826.export.CSV already exists
# 20200825.export.CSV already exists
# 20200824.export.CSV already exists
# 20200823.export.CSV already exists
# 20200822.export.CSV already exists
# 20200821.export.CSV already exists
# 20200820.export.CSV already exists
# 20200819.export.CSV already exists
# 20200818.export.CSV already exists
# 20200817.export.CSV already exists
# 20200816.export.CSV already exists
# 20200815.export.CSV already exists
# 20200814.export.CSV already exists
# 20200813.export.CSV already exists
# 20200812.export.CSV already exists
# 20200811.export.CSV already exists
# 20200810.export.CSV already exists
# 20200809.export.CSV already exists
# 20200808.export.CSV already exists
# 20200807.export.CSV already exists
# 20200806.export.CSV already exists
# 20200805.export.CSV already exists
# 20200804.export.CSV already exists
# 20200803.export.CSV already exists
# 20200802.export.CSV already exists
# 20200801.export.CSV already exists
# 20200731.export.CSV already exists
# 20200730.export.CSV already exists
# 20200729.export.CSV already exists
# 20200728.export.CSV already exists
# 20200727.export.CSV already exists
# 20200726.export.CSV already exists
# 20200725.export.CSV already exists
# 20200724.export.CSV already exists
# 20200723.export.CSV already exists
# 20200722.export.CSV already exists
# 20200721.export.CSV already exists
# 20200720.export.CSV already exists
# 20200719.export.CSV already exists
# 20200718.export.CSV already exists
# 20200717.export.CSV already exists
# 20200716.export.CSV already exists
# 20200715.export.CSV already exists
# 20200714.export.CSV already exists
# 20200713.export.CSV already exists
# 20200712.export.CSV already exists
# 20200711.export.CSV already exists
# 20200710.export.CSV already exists
# 20200709.export.CSV already exists
# 20200708.export.CSV already exists
# 20200707.export.CSV already exists
# 20200706.export.CSV already exists
# 20200705.export.CSV already exists
# 20200704.export.CSV already exists
# 20200703.export.CSV already exists
# 20200702.export.CSV already exists
# 20200701.export.CSV already exists
# 20200630.export.CSV already exists
# 20200629.export.CSV already exists
# 20200628.export.CSV already exists
# 20200627.export.CSV already exists
# 20200626.export.CSV already exists
# 20200625.export.CSV already exists
# 20200624.export.CSV already exists
# 20200623.export.CSV already exists
# 20200622.export.CSV already exists
# 20200621.export.CSV already exists
# 20200620.export.CSV already exists
# 20200619.export.CSV already exists
# 20200618.export.CSV already exists
# 20200617.export.CSV already exists
# 20200616.export.CSV already exists
# 20200615.export.CSV already exists
# 20200614.export.CSV already exists
# 20200613.export.CSV already exists
# 20200612.export.CSV already exists
# 20200611.export.CSV already exists
# 20200610.export.CSV already exists
# 20200609.export.CSV already exists
# 20200608.export.CSV already exists
# 20200607.export.CSV already exists
# 20200606.export.CSV already exists
# 20200605.export.CSV already exists
# 20200604.export.CSV already exists
# 20200603.export.CSV already exists
# 20200602.export.CSV already exists
# 20200601.export.CSV already exists
# 20200531.export.CSV already exists
# 20200530.export.CSV already exists
# 20200529.export.CSV already exists
# 20200528.export.CSV already exists
# 20200527.export.CSV already exists
# 20200526.export.CSV already exists
# 20200525.export.CSV already exists
# 20200524.export.CSV already exists
# 20200523.export.CSV already exists
# 20200522.export.CSV already exists
# 20200521.export.CSV already exists
# 20200520.export.CSV already exists
# 20200519.export.CSV already exists
# 20200518.export.CSV already exists
# 20200517.export.CSV already exists
# 20200516.export.CSV already exists
# 20200515.export.CSV already exists
# 20200514.export.CSV already exists
# 20200513.export.CSV already exists
# 20200512.export.CSV already exists
# 20200511.export.CSV already exists
# 20200510.export.CSV already exists
# 20200509.export.CSV already exists
# 20200508.export.CSV already exists
# 20200507.export.CSV already exists
# 20200506.export.CSV already exists
# 20200505.export.CSV already exists
# 20200504.export.CSV already exists
# 20200503.export.CSV already exists
# 20200502.export.CSV already exists
# 20200501.export.CSV already exists
# 20200430.export.CSV already exists
# 20200429.export.CSV already exists
# 20200428.export.CSV already exists
# 20200427.export.CSV already exists
# 20200426.export.CSV already exists
# 20200425.export.CSV already exists
# 20200424.export.CSV already exists
# 20200423.export.CSV already exists
# 20200422.export.CSV already exists
# 20200421.export.CSV already exists
# 20200420.export.CSV already exists
# 20200419.export.CSV already exists
# 20200418.export.CSV already exists
# 20200417.export.CSV already exists
# 20200416.export.CSV already exists
# 20200415.export.CSV already exists
# 20200414.export.CSV already exists
# 20200413.export.CSV already exists
# 20200412.export.CSV already exists
# 20200411.export.CSV already exists
# 20200410.export.CSV already exists
# 20200409.export.CSV already exists
# 20200408.export.CSV already exists
# 20200407.export.CSV already exists
# 20200406.export.CSV already exists
# 20200405.export.CSV already exists
# 20200404.export.CSV already exists
# 20200403.export.CSV already exists
# 20200402.export.CSV already exists
# 20200401.export.CSV already exists
# 20200331.export.CSV already exists
# 20200330.export.CSV already exists
# 20200329.export.CSV already exists
# 20200328.export.CSV already exists
# 20200327.export.CSV already exists
# 20200326.export.CSV already exists
# 20200325.export.CSV already exists
# 20200324.export.CSV already exists
# 20200323.export.CSV already exists
# 20200322.export.CSV already exists
# 20200321.export.CSV already exists
# 20200320.export.CSV already exists
# 20200319.export.CSV already exists
# 20200318.export.CSV already exists
# 20200317.export.CSV already exists
# 20200316.export.CSV already exists
# 20200315.export.CSV already exists
# 20200314.export.CSV already exists
# 20200313.export.CSV already exists
# 20200312.export.CSV already exists
# 20200311.export.CSV already exists
# 20200310.export.CSV already exists
# 20200309.export.CSV already exists
# 20200308.export.CSV already exists
# 20200307.export.CSV already exists
# 20200306.export.CSV already exists
# 20200305.export.CSV already exists
# 20200304.export.CSV already exists
# 20200303.export.CSV already exists
# 20200302.export.CSV already exists
# 20200301.export.CSV already exists
# 20200229.export.CSV already exists
# 20200228.export.CSV already exists
# 20200227.export.CSV already exists
# 20200226.export.CSV already exists
# 20200225.export.CSV already exists
# 20200224.export.CSV already exists
# 20200223.export.CSV already exists
# 20200222.export.CSV already exists
# 20200221.export.CSV already exists
# 20200220.export.CSV already exists
# 20200219.export.CSV already exists
# 20200218.export.CSV already exists
# 20200217.export.CSV already exists
# 20200216.export.CSV already exists
# 20200215.export.CSV already exists
# 20200214.export.CSV already exists
# 20200213.export.CSV already exists
# 20200212.export.CSV already exists
# 20200211.export.CSV already exists
# 20200210.export.CSV already exists
# 20200209.export.CSV already exists
# 20200208.export.CSV already exists
# 20200207.export.CSV already exists
# 20200206.export.CSV already exists
# 20200205.export.CSV already exists
# 20200204.export.CSV already exists
# 20200203.export.CSV already exists
# 20200202.export.CSV already exists
# 20200201.export.CSV already exists
# 20200131.export.CSV already exists
# 20200130.export.CSV already exists
# 20200129.export.CSV already exists
# 20200128.export.CSV already exists
# 20200127.export.CSV already exists
# 20200126.export.CSV already exists
# 20200125.export.CSV already exists
# 20200124.export.CSV already exists
# 20200123.export.CSV already exists
# 20200122.export.CSV already exists
# 20200121.export.CSV already exists
# 20200120.export.CSV already exists
# 20200119.export.CSV already exists
# 20200118.export.CSV already exists
# 20200117.export.CSV already exists
# 20200116.export.CSV already exists
# 20200115.export.CSV already exists
# 20200114.export.CSV already exists
# 20200113.export.CSV already exists
# 20200112.export.CSV already exists
# 20200111.export.CSV already exists
# 20200110.export.CSV already exists
# 20200109.export.CSV already exists
# 20200108.export.CSV already exists
# 20200107.export.CSV already exists
# 20200106.export.CSV already exists
# 20200105.export.CSV already exists
# 20200104.export.CSV already exists
# 20200103.export.CSV already exists
# 20200102.export.CSV already exists
# 20200101.export.CSV already exists
# 20191231.export.CSV already exists
# 20191230.export.CSV already exists
# 20191229.export.CSV already exists
# 20191228.export.CSV already exists
# 20191227.export.CSV already exists
# 20191226.export.CSV already exists
# 20191225.export.CSV already exists
# 20191224.export.CSV already exists
# 20191223.export.CSV already exists
# 20191222.export.CSV already exists
# 20191221.export.CSV already exists
# 20191220.export.CSV already exists
# 20191219.export.CSV already exists
# 20191218.export.CSV already exists
# 20191217.export.CSV already exists
# 20191216.export.CSV already exists
# 20191215.export.CSV already exists
# 20191214.export.CSV already exists
# 20191213.export.CSV already exists
# 20191212.export.CSV already exists
# 20191211.export.CSV already exists
# 20191210.export.CSV already exists
# 20191209.export.CSV already exists
# 20191208.export.CSV already exists
# 20191207.export.CSV already exists
# 20191206.export.CSV already exists
# 20191205.export.CSV already exists
# 20191204.export.CSV already exists
# 20191203.export.CSV already exists
# 20191202.export.CSV already exists
# 20191201.export.CSV already exists
# 20191130.export.CSV already exists
# 20191129.export.CSV already exists
# 20191128.export.CSV already exists
# 20191127.export.CSV already exists
# 20191126.export.CSV already exists
# 20191125.export.CSV already exists
# 20191124.export.CSV already exists
# 20191123.export.CSV already exists
# 20191122.export.CSV already exists
# 20191121.export.CSV already exists
# 20191120.export.CSV already exists
# 20191119.export.CSV already exists
# 20191118.export.CSV already exists
# 20191117.export.CSV already exists
# 20191116.export.CSV already exists
# 20191115.export.CSV already exists
# 20191114.export.CSV already exists
# 20191113.export.CSV already exists
# 20191112.export.CSV already exists
# 20191111.export.CSV already exists
# 20191110.export.CSV already exists
# 20191109.export.CSV already exists
# 20191108.export.CSV already exists
# 20191107.export.CSV already exists
# 20191106.export.CSV already exists
# 20191105.export.CSV already exists
# 20191104.export.CSV already exists
# 20191103.export.CSV already exists
# 20191102.export.CSV already exists
# 20191101.export.CSV already exists
# 20191031.export.CSV already exists
# 20191030.export.CSV already exists
# 20191029.export.CSV already exists
# 20191028.export.CSV already exists
# 20191027.export.CSV already exists
# 20191026.export.CSV already exists
# 20191025.export.CSV already exists
# 20191024.export.CSV already exists
# 20191023.export.CSV already exists
# 20191022.export.CSV already exists
# 20191021.export.CSV already exists
# 20191020.export.CSV already exists
# 20191019.export.CSV already exists
# 20191018.export.CSV already exists
# 20191017.export.CSV already exists
# 20191016.export.CSV already exists
# 20191015.export.CSV already exists
# 20191014.export.CSV already exists
# 20191013.export.CSV already exists
# 20191012.export.CSV already exists
# 20191011.export.CSV already exists
# 20191010.export.CSV already exists
# 20191009.export.CSV already exists
# 20191008.export.CSV already exists
# 20191007.export.CSV already exists
# 20191006.export.CSV already exists
# 20191005.export.CSV already exists
# 20191004.export.CSV already exists
# 20191003.export.CSV already exists
# 20191002.export.CSV already exists
# 20191001.export.CSV already exists
# 20190930.export.CSV already exists
# 20190929.export.CSV already exists
# 20190928.export.CSV already exists
# 20190927.export.CSV already exists
# 20190926.export.CSV already exists
# 20190925.export.CSV already exists
# 20190924.export.CSV already exists
# 20190923.export.CSV already exists
# 20190922.export.CSV already exists
# 20190921.export.CSV already exists
# 20190920.export.CSV already exists
# 20190919.export.CSV already exists
# 20190918.export.CSV already exists
# 20190917.export.CSV already exists
# 20190916.export.CSV already exists
# 20190915.export.CSV already exists
# 20190914.export.CSV already exists
# 20190913.export.CSV already exists
# 20190912.export.CSV already exists
# 20190911.export.CSV already exists
# 20190910.export.CSV already exists
# 20190909.export.CSV already exists
# 20190908.export.CSV already exists
# 20190907.export.CSV already exists
# 20190906.export.CSV already exists
# 20190905.export.CSV already exists
# 20190904.export.CSV already exists
# 20190903.export.CSV already exists
# 20190902.export.CSV already exists
# 20190901.export.CSV already exists
# 20190831.export.CSV already exists
# 20190830.export.CSV already exists
# 20190829.export.CSV already exists
# 20190828.export.CSV already exists
# 20190827.export.CSV already exists
# 20190826.export.CSV already exists
# 20190825.export.CSV already exists
# 20190824.export.CSV already exists
# 20190823.export.CSV already exists
# 20190822.export.CSV already exists
# 20190821.export.CSV already exists
# 20190820.export.CSV already exists
# 20190819.export.CSV already exists
# 20190818.export.CSV already exists
# 20190817.export.CSV already exists
# 20190816.export.CSV already exists
# 20190815.export.CSV already exists
# 20190814.export.CSV already exists
# 20190813.export.CSV already exists
# 20190812.export.CSV already exists
# 20190811.export.CSV already exists
# 20190810.export.CSV already exists
# ...
# 20160404.export.CSV already exists
# 20160403.export.CSV already exists
# 20160402.export.CSV already exists
# 20160401.export.CSV already exists
# 20160331.export.CSV already exists
# 20160330.export.CSV already exists
# 20160329.export.CSV already exists
# 20160328.export.CSV already exists
# 20160327.export.CSV already exists
# 20160326.export.CSV already exists
# 20160325.export.CSV already exists
# 20160324.export.CSV already exists
# 20160323.export.CSV already exists
# 20160322.export.CSV already exists
# 20160321.export.CSV already exists
# 20160320.export.CSV already exists
# 20160319.export.CSV already exists
# 20160318.export.CSV already exists
# 20160317.export.CSV already exists
# 20160316.export.CSV already exists
# 20160315.export.CSV already exists
# 20160314.export.CSV already exists
# 20160313.export.CSV already exists
# 20160312.export.CSV already exists
# 20160311.export.CSV already exists
# 20160310.export.CSV already exists
# 20160309.export.CSV already exists
# 20160308.export.CSV already exists
# 20160307.export.CSV already exists
# 20160306.export.CSV already exists
# 20160305.export.CSV already exists
# 20160304.export.CSV already exists
# 20160303.export.CSV already exists
# 20160302.export.CSV already exists
# 20160301.export.CSV already exists
# 20160229.export.CSV already exists
# 20160228.export.CSV already exists
# 20160227.export.CSV already exists
# 20160226.export.CSV already exists
# 20160225.export.CSV already exists
# 20160224.export.CSV already exists
# 20160223.export.CSV already exists
# 20160222.export.CSV already exists
# 20160221.export.CSV already exists
# 20160220.export.CSV already exists
# 20160219.export.CSV already exists
# 20160218.export.CSV already exists
# 20160217.export.CSV already exists
# 20160216.export.CSV already exists
# 20160215.export.CSV already exists
# 20160214.export.CSV already exists
# 20160213.export.CSV already exists
# 20160212.export.CSV already exists
# 20160211.export.CSV already exists
# 20160210.export.CSV already exists
# 20160209.export.CSV already exists
# 20160208.export.CSV already exists
# 20160207.export.CSV already exists
# 20160206.export.CSV already exists
# 20160205.export.CSV already exists
# 20160204.export.CSV already exists
# 20160203.export.CSV already exists
# 20160202.export.CSV already exists
# 20160201.export.CSV already exists
# 20160131.export.CSV already exists
# 20160130.export.CSV already exists
# 20160129.export.CSV already exists
# 20160128.export.CSV already exists
# 20160127.export.CSV already exists
# 20160126.export.CSV already exists
# 20160125.export.CSV already exists
# 20160124.export.CSV already exists
# 20160123.export.CSV already exists
# 20160122.export.CSV already exists
# 20160121.export.CSV already exists
# 20160120.export.CSV already exists
# 20160119.export.CSV already exists
# 20160118.export.CSV already exists
# 20160117.export.CSV already exists
# 20160116.export.CSV already exists
# 20160115.export.CSV already exists
# 20160114.export.CSV already exists
# 20160113.export.CSV already exists
# 20160112.export.CSV already exists
# 20160111.export.CSV already exists
# 20160110.export.CSV already exists
# 20160109.export.CSV already exists
# 20160108.export.CSV already exists
# 20160107.export.CSV already exists
# 20160106.export.CSV already exists
# 20160105.export.CSV already exists
# 20160104.export.CSV already exists
# 20160103.export.CSV already exists
# 20160102.export.CSV already exists
# 20160101.export.CSV already exists
# 20151231.export.CSV already exists
# 20151230.export.CSV already exists
# 20151229.export.CSV already exists
# 20151228.export.CSV already exists
# 20151227.export.CSV already exists
# 20151226.export.CSV already exists
# 20151225.export.CSV already exists
# 20151224.export.CSV already exists
# 20151223.export.CSV already exists
# 20151222.export.CSV already exists
# 20151221.export.CSV already exists
# 20151220.export.CSV already exists
# 20151219.export.CSV already exists
# 20151218.export.CSV already exists
# 20151217.export.CSV already exists
# 20151216.export.CSV already exists
# 20151215.export.CSV already exists
# 20151214.export.CSV already exists
# 20151213.export.CSV already exists
# 20151212.export.CSV already exists
# 20151211.export.CSV already exists
# 20151210.export.CSV already exists
# 20151209.export.CSV already exists
# 20151208.export.CSV already exists
# 20151207.export.CSV already exists
# 20151206.export.CSV already exists
# 20151205.export.CSV already exists
# 20151204.export.CSV already exists
# 20151203.export.CSV already exists
# 20151202.export.CSV already exists
# 20151201.export.CSV already exists
# 20151130.export.CSV already exists
# 20151129.export.CSV already exists
# 20151128.export.CSV already exists
# 20151127.export.CSV already exists
# 20151126.export.CSV already exists
# 20151125.export.CSV already exists
# 20151124.export.CSV already exists
# 20151123.export.CSV already exists
# 20151122.export.CSV already exists
# 20151121.export.CSV already exists
# 20151120.export.CSV already exists
# 20151119.export.CSV already exists
# 20151118.export.CSV already exists
# 20151117.export.CSV already exists
# 20151116.export.CSV already exists
# 20151115.export.CSV already exists
# 20151114.export.CSV already exists
# 20151113.export.CSV already exists
# 20151112.export.CSV already exists
# 20151111.export.CSV already exists
# 20151110.export.CSV already exists
# 20151109.export.CSV already exists
# 20151108.export.CSV already exists
# 20151107.export.CSV already exists
# 20151106.export.CSV already exists
# 20151105.export.CSV already exists
# 20151104.export.CSV already exists
# 20151103.export.CSV already exists
# 20151102.export.CSV already exists
# 20151101.export.CSV already exists
# 20151031.export.CSV already exists
# 20151030.export.CSV already exists
# 20151029.export.CSV already exists
# 20151028.export.CSV already exists
# 20151027.export.CSV already exists
# 20151026.export.CSV already exists
# 20151025.export.CSV already exists
# 20151024.export.CSV already exists
# 20151023.export.CSV already exists
# 20151022.export.CSV already exists
# 20151021.export.CSV already exists
# 20151020.export.CSV already exists
# 20151019.export.CSV already exists
# 20151018.export.CSV already exists
# 20151017.export.CSV already exists
# 20151016.export.CSV already exists
# 20151015.export.CSV already exists
# 20151014.export.CSV already exists
# 20151013.export.CSV already exists
# 20151012.export.CSV already exists
# 20151011.export.CSV already exists
# 20151010.export.CSV already exists
# 20151009.export.CSV already exists
# 20151008.export.CSV already exists
# 20151007.export.CSV already exists
# 20151006.export.CSV already exists
# 20151005.export.CSV already exists
# 20151004.export.CSV already exists
# 20151003.export.CSV already exists
# 20151002.export.CSV already exists
# 20151001.export.CSV already exists
# 20150930.export.CSV already exists
# 20150929.export.CSV already exists
# 20150928.export.CSV already exists
# 20150927.export.CSV already exists
# 20150926.export.CSV already exists
# 20150925.export.CSV already exists
# 20150924.export.CSV already exists
# 20150923.export.CSV already exists
# 20150922.export.CSV already exists
# 20150921.export.CSV already exists
# 20150920.export.CSV already exists
# 20150919.export.CSV already exists
# 20150918.export.CSV already exists
# 20150917.export.CSV already exists
# 20150916.export.CSV already exists
# 20150915.export.CSV already exists
# 20150914.export.CSV already exists
# 20150913.export.CSV already exists
# 20150912.export.CSV already exists
# 20150911.export.CSV already exists
# 20150910.export.CSV already exists
# 20150909.export.CSV already exists
# 20150908.export.CSV already exists
# 20150907.export.CSV already exists
# 20150906.export.CSV already exists
# 20150905.export.CSV already exists
# 20150904.export.CSV already exists
# 20150903.export.CSV already exists
# 20150902.export.CSV already exists
# 20150901.export.CSV already exists
# 20150831.export.CSV already exists
# 20150830.export.CSV already exists
# 20150829.export.CSV already exists
# 20150828.export.CSV already exists
# 20150827.export.CSV already exists
# 20150826.export.CSV already exists
# 20150825.export.CSV already exists
# 20150824.export.CSV already exists
# 20150823.export.CSV already exists
# 20150822.export.CSV already exists
# 20150821.export.CSV already exists
# 20150820.export.CSV already exists
# 20150819.export.CSV already exists
# 20150818.export.CSV already exists
# 20150817.export.CSV already exists
# 20150816.export.CSV already exists
# 20150815.export.CSV already exists
# 20150814.export.CSV already exists
# 20150813.export.CSV already exists
# 20150812.export.CSV already exists
# 20150811.export.CSV already exists
# 20150810.export.CSV already exists
# 20150809.export.CSV already exists
# 20150808.export.CSV already exists
# 20150807.export.CSV already exists
# 20150806.export.CSV already exists
# 20150805.export.CSV already exists
# 20150804.export.CSV already exists
# 20150803.export.CSV already exists
# 20150802.export.CSV already exists
# 20150801.export.CSV already exists
# 20150731.export.CSV already exists
# 20150730.export.CSV already exists
# 20150729.export.CSV already exists
# 20150728.export.CSV already exists
# 20150727.export.CSV already exists
# 20150726.export.CSV already exists
# 20150725.export.CSV already exists
# 20150724.export.CSV already exists
# 20150723.export.CSV already exists
# 20150722.export.CSV already exists
# 20150721.export.CSV already exists
# 20150720.export.CSV already exists
# 20150719.export.CSV already exists
# 20150718.export.CSV already exists
# 20150717.export.CSV already exists
# 20150716.export.CSV already exists
# 20150715.export.CSV already exists
# 20150714.export.CSV already exists
# 20150713.export.CSV already exists
# 20150712.export.CSV already exists
# 20150711.export.CSV already exists
# 20150710.export.CSV already exists
# 20150709.export.CSV already exists
# 20150708.export.CSV already exists
# 20150707.export.CSV already exists
# 20150706.export.CSV already exists
# 20150705.export.CSV already exists
# 20150704.export.CSV already exists
# 20150703.export.CSV already exists
# 20150702.export.CSV already exists
# 20150701.export.CSV already exists
# 20150630.export.CSV already exists
# 20150629.export.CSV already exists
# 20150628.export.CSV already exists
# 20150627.export.CSV already exists
# 20150626.export.CSV already exists
# 20150625.export.CSV already exists
# 20150624.export.CSV already exists
# 20150623.export.CSV already exists
# 20150622.export.CSV already exists
# 20150621.export.CSV already exists
# 20150620.export.CSV already exists
# 20150619.export.CSV already exists
# 20150618.export.CSV already exists
# 20150617.export.CSV already exists
# 20150616.export.CSV already exists
# 20150615.export.CSV already exists
# 20150614.export.CSV already exists
# 20150613.export.CSV already exists
# 20150612.export.CSV already exists
# 20150611.export.CSV already exists
# 20150610.export.CSV already exists
# 20150609.export.CSV already exists
# 20150608.export.CSV already exists
# 20150607.export.CSV already exists
# 20150606.export.CSV already exists
# 20150605.export.CSV already exists
# 20150604.export.CSV already exists
# 20150603.export.CSV already exists
# 20150602.export.CSV already exists
# 20150601.export.CSV already exists
# 20150531.export.CSV already exists
# 20150530.export.CSV already exists
# 20150529.export.CSV already exists
# 20150528.export.CSV already exists
# 20150527.export.CSV already exists
# 20150526.export.CSV already exists
# 20150525.export.CSV already exists
# 20150524.export.CSV already exists
# 20150523.export.CSV already exists
# 20150522.export.CSV already exists
# 20150521.export.CSV already exists
# 20150520.export.CSV already exists
# 20150519.export.CSV already exists
# 20150518.export.CSV already exists
# 20150517.export.CSV already exists
# 20150516.export.CSV already exists
# 20150515.export.CSV already exists
# 20150514.export.CSV already exists
# 20150513.export.CSV already exists
# 20150512.export.CSV already exists
# 20150511.export.CSV already exists
# 20150510.export.CSV already exists
# 20150509.export.CSV already exists
# 20150508.export.CSV already exists
# 20150507.export.CSV already exists
# 20150506.export.CSV already exists
# 20150505.export.CSV already exists
# 20150504.export.CSV already exists
# 20150503.export.CSV already exists
# 20150502.export.CSV already exists
# 20150501.export.CSV already exists
# 20150430.export.CSV already exists
# 20150429.export.CSV already exists
# 20150428.export.CSV already exists
# 20150427.export.CSV already exists
# 20150426.export.CSV already exists
# 20150425.export.CSV already exists
# 20150424.export.CSV already exists
# 20150423.export.CSV already exists
# 20150422.export.CSV already exists
# 20150421.export.CSV already exists
# 20150420.export.CSV already exists
# 20150419.export.CSV already exists
# 20150418.export.CSV already exists
# 20150417.export.CSV already exists
# 20150416.export.CSV already exists
# 20150415.export.CSV already exists
# 20150414.export.CSV already exists
# 20150413.export.CSV already exists
# 20150412.export.CSV already exists
# 20150411.export.CSV already exists
# 20150410.export.CSV already exists
# 20150409.export.CSV already exists
# 20150408.export.CSV already exists
# 20150407.export.CSV already exists
# 20150406.export.CSV already exists
# 20150405.export.CSV already exists
# 20150404.export.CSV already exists
# 20150403.export.CSV already exists
# 20150402.export.CSV already exists
# 20150401.export.CSV already exists
# 20150331.export.CSV already exists
# 20150330.export.CSV already exists
# 20150329.export.CSV already exists
# 20150328.export.CSV already exists
# 20150327.export.CSV already exists
# 20150326.export.CSV already exists
# 20150325.export.CSV extracted succesfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7204/4286203160.py in <module>
# ----> 1 GDELTextracter(verbose= True)
#
# /tmp/ipykernel_7204/654470302.py in GDELTextracter(verbose)
#      14             if os.path.exists(zipfilepath):
#      15                 with zipfile.ZipFile(zipfilepath,'r') as zip_ref:
# ---> 16                     zip_ref.extractall(csvpath)
#      17                     if verbose: print(f"{sqldate}.export.CSV extracted succesfully")
#      18             else:
#
# ~/anaconda3/lib/python3.9/zipfile.py in extractall(self, path, members, pwd)
#    1640
#    1641         for zipinfo in members:
# -> 1642             self._extract_member(zipinfo, path, pwd)
#    1643
#    1644     @classmethod
#
# ~/anaconda3/lib/python3.9/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1695         with self.open(member, pwd=pwd) as source, \
#    1696              open(targetpath, "wb") as target:
# -> 1697             shutil.copyfileobj(source, target)
#    1698
#    1699         return targetpath
#
# ~/anaconda3/lib/python3.9/shutil.py in copyfileobj(fsrc, fdst, length)
#     203     fdst_write = fdst.write
#     204     while True:
# --> 205         buf = fsrc_read(length)
#     206         if not buf:
#     207             break
#
# ~/anaconda3/lib/python3.9/zipfile.py in read(self, n)
#     922         self._offset = 0
#     923         while n > 0 and not self._eof:
# --> 924             data = self._read1(n)
#     925             if n < len(data):
#     926                 self._readbuffer = data
#
# ~/anaconda3/lib/python3.9/zipfile.py in _read1(self, n)
#     990             data = self._decompressor.unconsumed_tail
#     991             if n > len(data):
# --> 992                 data += self._read2(n - len(data))
#     993         else:
#     994             data = self._read2(n)
#
# ~/anaconda3/lib/python3.9/zipfile.py in _read2(self, n)
#    1022         n = min(n, self._compress_left)
#    1023
# -> 1024         data = self._fileobj.read(n)
#    1025         self._compress_left -= len(data)
#    1026         if not data:
#
# ~/anaconda3/lib/python3.9/zipfile.py in read(self, n)
#     737     def read(self, n=-1):
#     738         with self._lock:
# --> 739             if self._writing():
#     740                 raise ValueError("Can't read from the ZIP file while there "
#     741                         "is an open writing handle on it. "
#
# ~/anaconda3/lib/python3.9/zipfile.py in <lambda>()
#    1522         self._fileRefCnt += 1
#    1523         zef_file = _SharedFile(self.fp, zinfo.header_offset,
# -> 1524                                self._fpclose, self._lock, lambda: self._writing)
#    1525         try:
#    1526             # Skip the file header:
#
# KeyboardInterrupt:

# %%
def GDELTspider_and_extracter(return_missing_dates=False, verbose=False):
    delta = timedelta(days=1)  # Increment of one day
    start_date = datetime.strptime("20130401", "%Y%m%d")
    end_date = datetime.now() - delta  # Uses the date of yesterday as the date
    missing_dates = []

    while end_date >= start_date:
        sqldate = end_date.strftime("%Y%m%d")
        url = f"http://data.gdeltproject.org/events/{sqldate}.export.CSV.zip"
        csvpath = f"../data/gdelt_data/extracted/"
        zipfilepath = f"../data/gdelt_data/zips/{sqldate}.export.CSV.zip"
        csvfile = f"../data/gdelt_data/extracted/{sqldate}.export.CSV"

        if not os.path.exists(csvfile):
            try:
                # Download the zip
                urllib.request.urlretrieve(url, zipfilepath)
                if verbose:
                    print(f"File for SQLDATE {sqldate} downloaded successfully.")
                # Extract the csv
                with zipfile.ZipFile(zipfilepath, "r") as zip_ref:
                    zip_ref.extractall(csvpath)
                    if verbose:
                        print(f"{sqldate}.export.CSV extracted succesfully")
            except urllib.error.HTTPError as e:
                if e.code == 404:
                    if verbose:
                        print(f"URL for SQLDATE {sqldate} does not exist. Skipping.")
                    missing_dates.append(sqldate)
        else:
            if verbose:
                print(f"File for SQLDATE {sqldate} already exists. Skipping.")
        end_date -= delta

    if return_missing_dates:
        return missing_dates
